# %%
import base64
import IPython
import imageio

def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return IPython.display.HTML(tag)

def record_game(model, env, num_episodes=5, video_filename='video.mp4'):
    with imageio.get_writer(video_filename, fps=60) as video:
        for _ in range(num_episodes):
            obs = env.reset()
            done = False
            total_reward = 0
            video.append_data(env.render('rgb_array'))

            while not done:
                action, _steps = model.predict(obs)
                obs, reward, done, info = env.step(action)
                total_reward += reward
                video.append_data(env.render('rgb_array'))

            print("score:", total_reward)

# %%
import os
import gym
import slimevolleygym
from slimevolleygym import SurvivalRewardEnv

from stable_baselines.common.policies import MlpPolicy  # for everything else
# from stable_baselines.deepq.policies import MlpPolicy  # for DQN
from stable_baselines import logger
from stable_baselines.common.callbacks import EvalCallback

from stable_baselines.ppo1 import PPO1
from stable_baselines import A2C, ACER, ACKTR, DQN, HER, GAIL, TRPO

algo = {
    'a2c': A2C,
    'acer': ACER,
    'acktr': ACKTR,
    'dqn': DQN,
    'her': HER,
    'gail': GAIL,
    'trpo': TRPO,
}
trained_model = {}

# %%
def experiment(model_str, timesteps=15_000_000):
    NUM_TIMESTEPS = int(timesteps)
    SEED = 721
    EVAL_FREQ = 25000
    EVAL_EPISODES = 10  # was 1000
    LOGDIR = "sb-" + model_str

    logger.configure(folder=LOGDIR)
    env = gym.make("SlimeVolley-v0")
    env.seed(SEED)

    model = algo[model_str](MlpPolicy, env, verbose=2)
    trained_model[model_str] = model
    eval_callback = EvalCallback(env, best_model_save_path=LOGDIR, log_path=LOGDIR, eval_freq=EVAL_FREQ, n_eval_episodes=EVAL_EPISODES)
    model.learn(total_timesteps=NUM_TIMESTEPS, callback=eval_callback)
    model.save(os.path.join(LOGDIR, "final_model")) # probably never get to this point.
    env.close()

# %%
experiment('trpo')
# Out:
# Logging to sb-trpo
# ********** Iteration 0 ************
# Optimizing Policy...
# C:\Users\notes\Anaconda3\envs\slime-rl\lib\site-packages\stable_baselines\common\callbacks.py:287: UserWarning: Training and eval env are not of the same type<SlimeVolleyEnv<SlimeVolley-v0>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x000002A4BE267B08>
#   "{} != {}".format(self.training_env, self.eval_env))
# sampling
# done in 0.789 seconds
# computegrad
# done in 0.127 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0133          0
#          1    0.00505      0.154
#          2    0.00283      0.257
#          3    0.00119      0.391
#          4   0.000913      0.533
#          5   0.000806      0.816
#          6   0.000742       1.11
#          7   0.000239       1.26
#          8   0.000428       1.29
#          9   8.96e-05       1.36
#         10   1.92e-05       1.43
# done in 0.152 seconds
# Expected: 0.034 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.084 seconds
# ------------------------------------------
# | EpLenMean               | 981          |
# | EpRewMean               | -4           |
# | EpThisIter              | 1            |
# | EpisodesSoFar           | 1            |
# | TimeElapsed             | 1.25         |
# | TimestepsSoFar          | 1024         |
# | entloss                 | 0.0          |
# | entropy                 | 2.0729797    |
# | explained_variance_t... | 0.116        |
# | meankl                  | 0.0066130664 |
# | optimgain               | 0.033846814  |
# | surrgain                | 0.033846814  |
# ------------------------------------------
# ********** Iteration 1 ************
# Optimizing Policy...
# sampling
# done in 0.836 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00813          0
#          1    0.00761     0.0823
#          2    0.00478      0.251
#          3    0.00395      0.451
#          4    0.00239      0.522
#          5    0.00218      0.734
#          6    0.00181      0.968
#          7    0.00262       1.16
#          8    0.00237       1.27
#          9   0.000893       1.54
#         10   0.000249       1.79
# done in 0.024 seconds
# Expected: 0.037 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.047 seconds
# ------------------------------------------
# | EpLenMean               | 654          |
# | EpRewMean               | -4.67        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 3            |
# | TimeElapsed             | 2.18         |
# | TimestepsSoFar          | 2048         |
# | entloss                 | 0.0          |
# | entropy                 | 2.0630293    |
# | explained_variance_t... | 0.538        |
# | meankl                  | 0.0071897623 |
# | optimgain               | 0.03431412   |
# | surrgain                | 0.03431412   |
# ------------------------------------------
# ********** Iteration 2 ************
# Optimizing Policy...
# sampling
# done in 0.809 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0165          0
#          1    0.00605     0.0808
#          2    0.00435      0.217
#          3    0.00622      0.424
#          4    0.00403       0.53
#          5    0.00603      0.691
#          6    0.00433      0.837
#          7    0.00243       1.09
#          8     0.0016       1.32
#          9    0.00103       1.57
#         10    0.00047       1.67
# done in 0.020 seconds
# Expected: 0.039 Actual: 0.037
# Stepsize OK!
# vf
# done in 0.041 seconds
# -----------------------------------------
# | EpLenMean               | 579         |
# | EpRewMean               | -4.8        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 5           |
# | TimeElapsed             | 3.08        |
# | TimestepsSoFar          | 3072        |
# | entloss                 | 0.0         |
# | entropy                 | 2.0596275   |
# | explained_variance_t... | 0.608       |
# | meankl                  | 0.007280549 |
# | optimgain               | 0.037365034 |
# | surrgain                | 0.037365034 |
# -----------------------------------------
# ********** Iteration 3 ************
# Optimizing Policy...
# sampling
# done in 0.838 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0325          0
#          1     0.0117     0.0951
#          2    0.00679      0.184
#          3    0.00495      0.223
#          4    0.00384      0.425
#          5    0.00671      0.516
#          6    0.00281      0.785
#          7    0.00436       1.11
#          8    0.00352       1.44
#          9    0.00104       1.66
#         10   0.000347       1.73
# done in 0.033 seconds
# Expected: 0.042 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.055 seconds
# -----------------------------------------
# | EpLenMean               | 555         |
# | EpRewMean               | -4.86       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 7           |
# | TimeElapsed             | 4.04        |
# | TimestepsSoFar          | 4096        |
# | entloss                 | 0.0         |
# | entropy                 | 2.0543501   |
# | explained_variance_t... | 0.547       |
# | meankl                  | 0.007028765 |
# | optimgain               | 0.04007071  |
# | surrgain                | 0.04007071  |
# -----------------------------------------
# ********** Iteration 4 ************
# Optimizing Policy...
# sampling
# done in 0.775 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00904          0
#          1    0.00821     0.0723
#          2     0.0033      0.147
#          3     0.0045      0.212
#          4    0.00282      0.307
#          5    0.00325      0.567
#          6    0.00701      0.711
#          7    0.00258       1.05
#          8    0.00117       1.33
#          9    0.00058       1.46
#         10   0.000352       1.52
# done in 0.025 seconds
# Expected: 0.033 Actual: 0.031
# Stepsize OK!
# vf
# done in 0.048 seconds
# -----------------------------------------
# | EpLenMean               | 550         |
# | EpRewMean               | -4.89       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 9           |
# | TimeElapsed             | 4.92        |
# | TimestepsSoFar          | 5120        |
# | entloss                 | 0.0         |
# | entropy                 | 2.0464697   |
# | explained_variance_t... | 0.613       |
# | meankl                  | 0.007011533 |
# | optimgain               | 0.031206958 |
# | surrgain                | 0.031206958 |
# -----------------------------------------
# ********** Iteration 5 ************
# Optimizing Policy...
# sampling
# done in 0.748 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00927          0
#          1     0.0093     0.0618
#          2    0.00352      0.187
#          3    0.00739      0.395
#          4    0.00571      0.477
#          5     0.0041      0.651
#          6      0.004      0.717
#          7    0.00292       1.01
#          8    0.00111       1.21
#          9   0.000828       1.41
#         10   0.000609        1.5
# done in 0.022 seconds
# Expected: 0.036 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.046 seconds
# ------------------------------------------
# | EpLenMean               | 554          |
# | EpRewMean               | -4.91        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 11           |
# | TimeElapsed             | 5.76         |
# | TimestepsSoFar          | 6144         |
# | entloss                 | 0.0          |
# | entropy                 | 2.037291     |
# | explained_variance_t... | 0.56         |
# | meankl                  | 0.0058818543 |
# | optimgain               | 0.032112014  |
# | surrgain                | 0.032112014  |
# ------------------------------------------
# ********** Iteration 6 ************
# Optimizing Policy...
# sampling
# done in 0.759 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0103          0
#          1     0.0141     0.0564
#          2    0.00767      0.243
#          3    0.00403      0.281
#          4    0.00333       0.46
#          5    0.00172      0.622
#          6    0.00502      0.739
#          7    0.00406      0.823
#          8    0.00181       1.19
#          9   0.000539       1.39
#         10   0.000617       1.52
# done in 0.022 seconds
# Expected: 0.036 Actual: 0.031
# Stepsize OK!
# vf
# done in 0.045 seconds
# -----------------------------------------
# | EpLenMean               | 537         |
# | EpRewMean               | -4.92       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 13          |
# | TimeElapsed             | 6.62        |
# | TimestepsSoFar          | 7168        |
# | entloss                 | 0.0         |
# | entropy                 | 2.0336356   |
# | explained_variance_t... | 0.507       |
# | meankl                  | 0.007651411 |
# | optimgain               | 0.03103182  |
# | surrgain                | 0.03103182  |
# -----------------------------------------
# ********** Iteration 7 ************
# Optimizing Policy...
# sampling
# done in 0.672 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0301          0
#          1      0.017     0.0748
#          2    0.00699      0.261
#          3     0.0315      0.426
#          4     0.0068      0.688
#          5     0.0253      0.851
#          6    0.00734       1.14
#          7    0.00506       1.57
#          8    0.00339       1.87
#          9    0.00167       2.08
#         10    0.00127       2.21
# done in 0.020 seconds
# Expected: 0.053 Actual: 0.052
# Stepsize OK!
# vf
# done in 0.043 seconds
# ------------------------------------------
# | EpLenMean               | 539          |
# | EpRewMean               | -4.93        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 15           |
# | TimeElapsed             | 7.38         |
# | TimestepsSoFar          | 8192         |
# | entloss                 | 0.0          |
# | entropy                 | 2.0328465    |
# | explained_variance_t... | 0.319        |
# | meankl                  | 0.0076340297 |
# | optimgain               | 0.05221813   |
# | surrgain                | 0.05221813   |
# ------------------------------------------
# ********** Iteration 8 ************
# Optimizing Policy...
# sampling
# done in 0.680 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0281          0
#          1     0.0143     0.0482
#          2     0.0205      0.242
#          3     0.0074      0.307
#          4    0.00452      0.454
#          5     0.0167      0.548
#          6    0.00576      0.792
#          7    0.00492       1.06
#          8    0.00284       1.58
#          9    0.00118       1.84
#         10   0.000912       1.92
# done in 0.023 seconds
# Expected: 0.046 Actual: 0.045
# Stepsize OK!
# vf
# done in 0.040 seconds
# -----------------------------------------
# | EpLenMean               | 536         |
# | EpRewMean               | -4.94       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 17          |
# | TimeElapsed             | 8.15        |
# | TimestepsSoFar          | 9216        |
# | entloss                 | 0.0         |
# | entropy                 | 2.0332584   |
# | explained_variance_t... | 0.532       |
# | meankl                  | 0.009456515 |
# | optimgain               | 0.045174353 |
# | surrgain                | 0.045174353 |
# -----------------------------------------
# ********** Iteration 9 ************
# Optimizing Policy...
# sampling
# done in 0.660 seconds
# computegrad
# done in 0.008 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0411          0
#          1     0.0304     0.0812
#          2     0.0138      0.196
#          3     0.0132      0.247
#          4    0.00762      0.395
#          5     0.0155      0.484
#          6    0.00751      0.695
#          7    0.00495      0.994
#          8    0.00261       1.46
#          9    0.00266       1.72
#         10     0.0016       1.84
# done in 0.021 seconds
# Expected: 0.050 Actual: 0.046
# Stepsize OK!
# vf
# done in 0.042 seconds
# ------------------------------------------
# | EpLenMean               | 531          |
# | EpRewMean               | -4.95        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 19           |
# | TimeElapsed             | 8.9          |
# | TimestepsSoFar          | 10240        |
# | entloss                 | 0.0          |
# | entropy                 | 2.0221295    |
# | explained_variance_t... | 0.666        |
# | meankl                  | 0.0074325213 |
# | optimgain               | 0.046441842  |
# | surrgain                | 0.046441842  |
# ------------------------------------------
# ********** Iteration 10 ************
# Optimizing Policy...
# sampling
# done in 0.718 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.028          0
#          1     0.0147     0.0745
#          2     0.0114      0.221
#          3     0.0211      0.371
#          4    0.00731      0.559
#          5    0.00826      0.687
#          6     0.0117      0.853
#          7     0.0059       1.14
#          8    0.00551       1.41
#          9    0.00365       1.74
#         10    0.00218        1.9
# done in 0.023 seconds
# Expected: 0.049 Actual: 0.048
# Stepsize OK!
# vf
# done in 0.041 seconds
# ------------------------------------------
# | EpLenMean               | 531          |
# | EpRewMean               | -4.95        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 21           |
# | TimeElapsed             | 9.71         |
# | TimestepsSoFar          | 11264        |
# | entloss                 | 0.0          |
# | entropy                 | 2.0179124    |
# | explained_variance_t... | 0.692        |
# | meankl                  | 0.0075504463 |
# | optimgain               | 0.048158713  |
# | surrgain                | 0.048158713  |
# ------------------------------------------
# ********** Iteration 11 ************
# Optimizing Policy...
# sampling
# done in 0.634 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0384          0
#          1     0.0193     0.0631
#          2     0.0139      0.204
#          3     0.0172       0.28
#          4    0.00749      0.439
#          5     0.0119      0.605
#          6    0.00606      0.684
#          7    0.00972       1.15
#          8    0.00464       1.55
#          9     0.0033       1.76
#         10    0.00177       2.03
# done in 0.021 seconds
# Expected: 0.050 Actual: 0.046
# Stepsize OK!
# vf
# done in 0.044 seconds
# -----------------------------------------
# | EpLenMean               | 531         |
# | EpRewMean               | -4.96       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 23          |
# | TimeElapsed             | 10.4        |
# | TimestepsSoFar          | 12288       |
# | entloss                 | 0.0         |
# | entropy                 | 2.0192955   |
# | explained_variance_t... | 0.692       |
# | meankl                  | 0.007794041 |
# | optimgain               | 0.04644927  |
# | surrgain                | 0.04644927  |
# -----------------------------------------
# ********** Iteration 12 ************
# Optimizing Policy...
# sampling
# done in 0.713 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0417          0
#          1     0.0162     0.0624
#          2     0.0164      0.193
#          3     0.0161      0.295
#          4    0.00932      0.432
#          5     0.0166      0.648
#          6    0.00894      0.796
#          7     0.0131       1.11
#          8     0.0067       1.62
#          9    0.00529       1.86
#         10    0.00333       2.06
# done in 0.023 seconds
# Expected: 0.052 Actual: 0.043
# Stepsize OK!
# vf
# done in 0.043 seconds
# -----------------------------------------
# | EpLenMean               | 530         |
# | EpRewMean               | -4.96       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 25          |
# | TimeElapsed             | 11.2        |
# | TimestepsSoFar          | 13312       |
# | entloss                 | 0.0         |
# | entropy                 | 2.0077963   |
# | explained_variance_t... | 0.666       |
# | meankl                  | 0.007661475 |
# | optimgain               | 0.043302163 |
# | surrgain                | 0.043302163 |
# -----------------------------------------
# ********** Iteration 13 ************
# Optimizing Policy...
# sampling
# done in 0.658 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.051          0
#          1     0.0219     0.0856
#          2    0.00959      0.182
#          3     0.0259      0.297
#          4     0.0114      0.573
#          5     0.0179       0.93
#          6     0.0246       1.13
#          7    0.00982       1.48
#          8    0.00387       1.79
#          9    0.00611       2.01
#         10    0.00283       2.23
# done in 0.020 seconds
# Expected: 0.057 Actual: 0.054
# Stepsize OK!
# vf
# done in 0.038 seconds
# ------------------------------------------
# | EpLenMean               | 534          |
# | EpRewMean               | -4.96        |
# | EpThisIter              | 1            |
# | EpisodesSoFar           | 26           |
# | TimeElapsed             | 12           |
# | TimestepsSoFar          | 14336        |
# | entloss                 | 0.0          |
# | entropy                 | 1.997586     |
# | explained_variance_t... | 0.347        |
# | meankl                  | 0.0071586636 |
# | optimgain               | 0.054157395  |
# | surrgain                | 0.054157395  |
# ------------------------------------------
# ********** Iteration 14 ************
# Optimizing Policy...
# sampling
# done in 0.642 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0427          0
#          1      0.021     0.0834
#          2     0.0137      0.203
#          3     0.0117      0.293
#          4     0.0121      0.426
#          5     0.0111      0.791
#          6     0.0159       1.01
#          7    0.00842       1.17
#          8    0.00739       1.45
#          9    0.00408       1.74
#         10    0.00373       1.94
# done in 0.021 seconds
# Expected: 0.052 Actual: 0.051
# Stepsize OK!
# vf
# done in 0.041 seconds
# ------------------------------------------
# | EpLenMean               | 544          |
# | EpRewMean               | -4.93        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 28           |
# | TimeElapsed             | 12.7         |
# | TimestepsSoFar          | 15360        |
# | entloss                 | 0.0          |
# | entropy                 | 1.9965316    |
# | explained_variance_t... | 0.549        |
# | meankl                  | 0.0090389885 |
# | optimgain               | 0.050508596  |
# | surrgain                | 0.050508596  |
# ------------------------------------------
# ********** Iteration 15 ************
# Optimizing Policy...
# sampling
# done in 0.636 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0472          0
#          1     0.0278     0.0778
#          2     0.0112      0.222
#          3     0.0229      0.303
#          4     0.0154      0.493
#          5     0.0174      0.605
#          6    0.00729       0.89
#          7    0.00779        1.2
#          8    0.00637       1.52
#          9    0.00485       1.78
#         10    0.00279       2.12
# done in 0.022 seconds
# Expected: 0.055 Actual: 0.053
# Stepsize OK!
# vf
# done in 0.042 seconds
# -----------------------------------------
# | EpLenMean               | 544         |
# | EpRewMean               | -4.9        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 30          |
# | TimeElapsed             | 13.4        |
# | TimestepsSoFar          | 16384       |
# | entloss                 | 0.0         |
# | entropy                 | 1.9904978   |
# | explained_variance_t... | 0.676       |
# | meankl                  | 0.008425934 |
# | optimgain               | 0.052685104 |
# | surrgain                | 0.052685104 |
# -----------------------------------------
# ********** Iteration 16 ************
# Optimizing Policy...
# sampling
# done in 0.676 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0309          0
#          1     0.0171     0.0814
#          2     0.0131      0.293
#          3     0.0115      0.381
#          4    0.00799      0.508
#          5     0.0108      0.657
#          6     0.0125       0.85
#          7    0.00614       1.29
#          8    0.00576       1.51
#          9     0.0032       1.72
#         10    0.00227       1.84
# done in 0.021 seconds
# Expected: 0.050 Actual: 0.048
# Stepsize OK!
# vf
# done in 0.063 seconds
# -----------------------------------------
# | EpLenMean               | 542         |
# | EpRewMean               | -4.9        |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 31          |
# | TimeElapsed             | 14.2        |
# | TimestepsSoFar          | 17408       |
# | entloss                 | 0.0         |
# | entropy                 | 1.96281     |
# | explained_variance_t... | 0.37        |
# | meankl                  | 0.008789364 |
# | optimgain               | 0.048255667 |
# | surrgain                | 0.048255667 |
# -----------------------------------------
# ********** Iteration 17 ************
# Optimizing Policy...
# sampling
# done in 0.702 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0382          0
#          1     0.0161     0.0847
#          2      0.017      0.181
#          3     0.0116      0.337
#          4    0.00882      0.431
#          5    0.00938      0.603
#          6     0.0132      0.757
#          7     0.0118       1.12
#          8    0.00464       1.43
#          9    0.00373       1.66
#         10    0.00315       1.83
# done in 0.024 seconds
# Expected: 0.049 Actual: 0.046
# Stepsize OK!
# vf
# done in 0.049 seconds
# -----------------------------------------
# | EpLenMean               | 541         |
# | EpRewMean               | -4.91       |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 34          |
# | TimeElapsed             | 15          |
# | TimestepsSoFar          | 18432       |
# | entloss                 | 0.0         |
# | entropy                 | 1.9429429   |
# | explained_variance_t... | 0.648       |
# | meankl                  | 0.007921351 |
# | optimgain               | 0.04614576  |
# | surrgain                | 0.04614576  |
# -----------------------------------------
# ********** Iteration 18 ************
# Optimizing Policy...
# sampling
# done in 0.671 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0175          0
#          1     0.0221     0.0793
#          2      0.014      0.256
#          3     0.0121       0.35
#          4     0.0132      0.536
#          5    0.00936       0.77
#          6     0.0115       1.12
#          7    0.00796       1.49
#          8     0.0114       1.67
#          9    0.00337       1.91
#         10    0.00166       2.05
# done in 0.022 seconds
# Expected: 0.051 Actual: 0.047
# Stepsize OK!
# vf
# done in 0.044 seconds
# ------------------------------------------
# | EpLenMean               | 548          |
# | EpRewMean               | -4.89        |
# | EpThisIter              | 1            |
# | EpisodesSoFar           | 35           |
# | TimeElapsed             | 15.8         |
# | TimestepsSoFar          | 19456        |
# | entloss                 | 0.0          |
# | entropy                 | 1.9334457    |
# | explained_variance_t... | 0.511        |
# | meankl                  | 0.0072553037 |
# | optimgain               | 0.0468046    |
# | surrgain                | 0.0468046    |
# ------------------------------------------
# ********** Iteration 19 ************
# Optimizing Policy...
# sampling
# done in 0.681 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0687          0
#          1     0.0156      0.114
#          2      0.024      0.223
#          3     0.0165      0.389
#          4     0.0159      0.581
#          5     0.0173      0.893
#          6     0.0207       1.18
#          7    0.00884       1.65
#          8    0.00823       1.82
#          9    0.00588       1.98
#         10    0.00245       2.14
# done in 0.020 seconds
# Expected: 0.060 Actual: 0.057
# Stepsize OK!
# vf
# done in 0.044 seconds
# -----------------------------------------
# | EpLenMean               | 553         |
# | EpRewMean               | -4.89       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 37          |
# | TimeElapsed             | 16.6        |
# | TimestepsSoFar          | 20480       |
# | entloss                 | 0.0         |
# | entropy                 | 1.930401    |
# | explained_variance_t... | 0.629       |
# | meankl                  | 0.009155822 |
# | optimgain               | 0.057049107 |
# | surrgain                | 0.057049107 |
# -----------------------------------------
# ********** Iteration 20 ************
# Optimizing Policy...
# sampling
# done in 0.693 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.045          0
#          1      0.021     0.0994
#          2     0.0166       0.21
#          3     0.0142      0.315
#          4     0.0202       0.65
#          5     0.0142      0.889
#          6     0.0117       1.07
#          7    0.00859       1.28
#          8    0.00882        1.6
#          9    0.00766        1.8
#         10    0.00472       1.94
# done in 0.022 seconds
# Expected: 0.055 Actual: 0.049
# Stepsize OK!
# vf
# done in 0.044 seconds
# ------------------------------------------
# | EpLenMean               | 556          |
# | EpRewMean               | -4.89        |
# | EpThisIter              | 1            |
# | EpisodesSoFar           | 38           |
# | TimeElapsed             | 17.3         |
# | TimestepsSoFar          | 21504        |
# | entloss                 | 0.0          |
# | entropy                 | 1.9281532    |
# | explained_variance_t... | 0.758        |
# | meankl                  | 0.0069790557 |
# | optimgain               | 0.049417138  |
# | surrgain                | 0.049417138  |
# ------------------------------------------
# ********** Iteration 21 ************
# Optimizing Policy...
# sampling
# done in 0.733 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0401          0
#          1     0.0181      0.113
#          2     0.0126      0.184
#          3     0.0128        0.4
#          4    0.00879      0.472
#          5     0.0129       0.71
#          6     0.0178       1.04
#          7     0.0132       1.24
#          8    0.00527       1.49
#          9    0.00322       1.86
#         10    0.00369       1.99
# done in 0.024 seconds
# Expected: 0.053 Actual: 0.047
# Stepsize OK!
# vf
# done in 0.047 seconds
# -----------------------------------------
# | EpLenMean               | 554         |
# | EpRewMean               | -4.9        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 40          |
# | TimeElapsed             | 18.2        |
# | TimestepsSoFar          | 22528       |
# | entloss                 | 0.0         |
# | entropy                 | 1.9059855   |
# | explained_variance_t... | 0.637       |
# | meankl                  | 0.008281932 |
# | optimgain               | 0.046899118 |
# | surrgain                | 0.046899118 |
# -----------------------------------------
# ********** Iteration 22 ************
# Optimizing Policy...
# sampling
# done in 0.718 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0454          0
#          1     0.0169     0.0799
#          2     0.0162      0.228
#          3     0.0131      0.431
#          4     0.0136      0.617
#          5     0.0115      0.844
#          6    0.00947       1.07
#          7    0.00767       1.24
#          8    0.00808        1.4
#          9    0.00273       1.53
#         10    0.00333       1.76
# done in 0.023 seconds
# Expected: 0.052 Actual: 0.053
# Stepsize OK!
# vf
# done in 0.041 seconds
# -----------------------------------------
# | EpLenMean               | 551         |
# | EpRewMean               | -4.92       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 42          |
# | TimeElapsed             | 19          |
# | TimestepsSoFar          | 23552       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8739164   |
# | explained_variance_t... | 0.66        |
# | meankl                  | 0.008676808 |
# | optimgain               | 0.05309876  |
# | surrgain                | 0.05309876  |
# -----------------------------------------
# ********** Iteration 23 ************
# Optimizing Policy...
# sampling
# done in 0.719 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.018          0
#          1     0.0167      0.102
#          2      0.012      0.182
#          3    0.00706      0.293
#          4     0.0147      0.426
#          5    0.00774      0.615
#          6    0.00755      0.753
#          7     0.0104      0.939
#          8    0.00394       1.07
#          9    0.00519       1.42
#         10    0.00476       1.61
# done in 0.020 seconds
# Expected: 0.043 Actual: 0.043
# Stepsize OK!
# vf
# done in 0.045 seconds
# -----------------------------------------
# | EpLenMean               | 552         |
# | EpRewMean               | -4.92       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 43          |
# | TimeElapsed             | 19.8        |
# | TimestepsSoFar          | 24576       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8730452   |
# | explained_variance_t... | 0.707       |
# | meankl                  | 0.008469244 |
# | optimgain               | 0.042707104 |
# | surrgain                | 0.042707104 |
# -----------------------------------------
# ********** Iteration 24 ************
# Optimizing Policy...
# sampling
# Eval num_timesteps=24576, episode_reward=-4.60 +/- 0.49
# Episode length: 573.20 +/- 83.05
# New best mean reward!
# done in 5.038 seconds
# computegrad
# done in 0.012 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0214          0
#          1     0.0102     0.0625
#          2     0.0123      0.148
#          3     0.0136      0.296
#          4     0.0088      0.413
#          5     0.0113      0.649
#          6    0.00879      0.814
#          7    0.00957       1.03
#          8    0.00396       1.26
#          9    0.00211       1.47
#         10    0.00223       1.62
# done in 0.021 seconds
# Expected: 0.043 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.041 seconds
# -----------------------------------------
# | EpLenMean               | 564         |
# | EpRewMean               | -4.95       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 45          |
# | TimeElapsed             | 24.9        |
# | TimestepsSoFar          | 25600       |
# | entloss                 | 0.0         |
# | entropy                 | 1.874361    |
# | explained_variance_t... | 0.615       |
# | meankl                  | 0.008164339 |
# | optimgain               | 0.04018122  |
# | surrgain                | 0.04018122  |
# -----------------------------------------
# ********** Iteration 25 ************
# Optimizing Policy...
# sampling
# done in 0.674 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0313          0
#          1     0.0117     0.0566
#          2     0.0144      0.211
#          3    0.00659      0.322
#          4    0.00771      0.409
#          5    0.00813      0.594
#          6     0.0114      0.812
#          7    0.00361      0.954
#          8    0.00463        1.1
#          9    0.00178       1.23
#         10    0.00227       1.35
# done in 0.027 seconds
# Expected: 0.041 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.050 seconds
# -----------------------------------------
# | EpLenMean               | 567         |
# | EpRewMean               | -4.95       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 47          |
# | TimeElapsed             | 25.7        |
# | TimestepsSoFar          | 26624       |
# | entloss                 | 0.0         |
# | entropy                 | 1.9070697   |
# | explained_variance_t... | 0.769       |
# | meankl                  | 0.008472563 |
# | optimgain               | 0.0400737   |
# | surrgain                | 0.0400737   |
# -----------------------------------------
# ********** Iteration 26 ************
# Optimizing Policy...
# sampling
# done in 0.713 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0433          0
#          1     0.0223      0.119
#          2      0.022      0.252
#          3     0.0241      0.445
#          4     0.0144      0.707
#          5     0.0141      0.908
#          6     0.0183       1.21
#          7     0.0123       1.39
#          8     0.0135        1.7
#          9    0.00694       1.97
#         10      0.005       2.34
# done in 0.022 seconds
# Expected: 0.062 Actual: 0.068
# Stepsize OK!
# vf
# done in 0.040 seconds
# -----------------------------------------
# | EpLenMean               | 567         |
# | EpRewMean               | -4.92       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 48          |
# | TimeElapsed             | 26.5        |
# | TimestepsSoFar          | 27648       |
# | entloss                 | 0.0         |
# | entropy                 | 1.9189188   |
# | explained_variance_t... | 0.386       |
# | meankl                  | 0.008943323 |
# | optimgain               | 0.06812069  |
# | surrgain                | 0.06812069  |
# -----------------------------------------
# ********** Iteration 27 ************
# Optimizing Policy...
# sampling
# done in 0.668 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0193          0
#          1     0.0218      0.121
#          2     0.0187      0.263
#          3     0.0154      0.407
#          4     0.0135      0.617
#          5     0.0134      0.804
#          6    0.00906       1.05
#          7     0.0106       1.23
#          8     0.0105       1.52
#          9    0.00303       1.66
#         10    0.00352       1.84
# done in 0.021 seconds
# Expected: 0.051 Actual: 0.050
# Stepsize OK!
# vf
# done in 0.045 seconds
# -----------------------------------------
# | EpLenMean               | 580         |
# | EpRewMean               | -4.88       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 49          |
# | TimeElapsed             | 27.3        |
# | TimestepsSoFar          | 28672       |
# | entloss                 | 0.0         |
# | entropy                 | 1.9235957   |
# | explained_variance_t... | 0.756       |
# | meankl                  | 0.009192082 |
# | optimgain               | 0.050052367 |
# | surrgain                | 0.050052367 |
# -----------------------------------------
# ********** Iteration 28 ************
# Optimizing Policy...
# sampling
# done in 0.658 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0162          0
#          1     0.0122     0.0758
#          2     0.0168      0.194
#          3     0.0164      0.368
#          4     0.0224      0.585
#          5    0.00629      0.856
#          6     0.0153       1.05
#          7    0.00607       1.26
#          8    0.00553       1.43
#          9    0.00427       1.62
#         10      0.004       1.82
# done in 0.023 seconds
# Expected: 0.048 Actual: 0.049
# Stepsize OK!
# vf
# done in 0.043 seconds
# -----------------------------------------
# | EpLenMean               | 580         |
# | EpRewMean               | -4.85       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 51          |
# | TimeElapsed             | 28          |
# | TimestepsSoFar          | 29696       |
# | entloss                 | 0.0         |
# | entropy                 | 1.9099162   |
# | explained_variance_t... | 0.778       |
# | meankl                  | 0.007980655 |
# | optimgain               | 0.048610218 |
# | surrgain                | 0.048610218 |
# -----------------------------------------
# ********** Iteration 29 ************
# Optimizing Policy...
# sampling
# done in 0.708 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0666          0
#          1     0.0278      0.137
#          2    0.00827      0.227
#          3     0.0168      0.345
#          4     0.0109      0.732
#          5     0.0159      0.962
#          6    0.00772       1.23
#          7     0.0123       1.58
#          8    0.00784       1.77
#          9    0.00675       1.91
#         10    0.00356       2.07
# done in 0.023 seconds
# Expected: 0.058 Actual: 0.053
# Stepsize OK!
# vf
# done in 0.041 seconds
# -----------------------------------------
# | EpLenMean               | 590         |
# | EpRewMean               | -4.85       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 53          |
# | TimeElapsed             | 28.8        |
# | TimestepsSoFar          | 30720       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8920915   |
# | explained_variance_t... | 0.584       |
# | meankl                  | 0.008458739 |
# | optimgain               | 0.052954726 |
# | surrgain                | 0.052954726 |
# -----------------------------------------
# ********** Iteration 30 ************
# Optimizing Policy...
# sampling
# done in 0.686 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0357          0
#          1     0.0158      0.122
#          2    0.00679      0.259
#          3     0.0147      0.378
#          4     0.0101      0.627
#          5     0.0173      0.934
#          6    0.00607       1.14
#          7    0.00886       1.43
#          8     0.0105       1.68
#          9    0.00289        1.9
#         10    0.00441       1.99
# done in 0.020 seconds
# Expected: 0.052 Actual: 0.048
# Stepsize OK!
# vf
# done in 0.041 seconds
# ----------------------------------------
# | EpLenMean               | 596        |
# | EpRewMean               | -4.83      |
# | EpThisIter              | 1          |
# | EpisodesSoFar           | 54         |
# | TimeElapsed             | 29.6       |
# | TimestepsSoFar          | 31744      |
# | entloss                 | 0.0        |
# | entropy                 | 1.8842943  |
# | explained_variance_t... | 0.442      |
# | meankl                  | 0.00742327 |
# | optimgain               | 0.04793732 |
# | surrgain                | 0.04793732 |
# ----------------------------------------
# ********** Iteration 31 ************
# Optimizing Policy...
# sampling
# done in 0.696 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0281          0
#          1    0.00963     0.0699
#          2    0.00853      0.127
#          3     0.0108      0.235
#          4    0.00977      0.391
#          5     0.0122      0.655
#          6      0.012      0.879
#          7    0.00791       1.05
#          8    0.00365       1.23
#          9    0.00613       1.41
#         10    0.00482       1.62
# done in 0.018 seconds
# Expected: 0.043 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.038 seconds
# -----------------------------------------
# | EpLenMean               | 599         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 56          |
# | TimeElapsed             | 30.4        |
# | TimestepsSoFar          | 32768       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8874174   |
# | explained_variance_t... | 0.797       |
# | meankl                  | 0.008183575 |
# | optimgain               | 0.04109183  |
# | surrgain                | 0.04109183  |
# -----------------------------------------
# ********** Iteration 32 ************
# Optimizing Policy...
# sampling
# done in 0.685 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0309          0
#          1     0.0131     0.0747
#          2     0.0213      0.205
#          3     0.0123      0.364
#          4     0.0164      0.541
#          5     0.0148      0.873
#          6     0.0137       1.12
#          7     0.0095       1.38
#          8    0.00671       1.53
#          9      0.006       1.71
#         10    0.00518       1.84
# done in 0.024 seconds
# Expected: 0.051 Actual: 0.052
# Stepsize OK!
# vf
# done in 0.045 seconds
# -----------------------------------------
# | EpLenMean               | 608         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 57          |
# | TimeElapsed             | 31.2        |
# | TimestepsSoFar          | 33792       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8499289   |
# | explained_variance_t... | 0.819       |
# | meankl                  | 0.008657148 |
# | optimgain               | 0.052255508 |
# | surrgain                | 0.052255508 |
# -----------------------------------------
# ********** Iteration 33 ************
# Optimizing Policy...
# sampling
# done in 0.744 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0343          0
#          1     0.0173      0.099
#          2     0.0228      0.223
#          3      0.012       0.39
#          4     0.0103       0.52
#          5     0.0175      0.736
#          6     0.0133       1.02
#          7     0.0121       1.31
#          8     0.0031       1.57
#          9    0.00615       1.68
#         10    0.00458       1.84
# done in 0.023 seconds
# Expected: 0.052 Actual: 0.047
# Stepsize OK!
# vf
# done in 0.040 seconds
# -----------------------------------------
# | EpLenMean               | 610         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 58          |
# | TimeElapsed             | 32          |
# | TimestepsSoFar          | 34816       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8122846   |
# | explained_variance_t... | 0.777       |
# | meankl                  | 0.008109737 |
# | optimgain               | 0.047220793 |
# | surrgain                | 0.047220793 |
# -----------------------------------------
# ********** Iteration 34 ************
# Optimizing Policy...
# sampling
# done in 0.671 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0195          0
#          1     0.0153     0.0849
#          2      0.014      0.223
#          3     0.0158      0.358
#          4     0.0145      0.682
#          5     0.0109      0.883
#          6    0.00728       1.09
#          7    0.00518       1.22
#          8    0.00592       1.41
#          9    0.00518       1.52
#         10    0.00368        1.7
# done in 0.021 seconds
# Expected: 0.048 Actual: 0.047
# Stepsize OK!
# vf
# done in 0.042 seconds
# -----------------------------------------
# | EpLenMean               | 624         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 60          |
# | TimeElapsed             | 32.8        |
# | TimestepsSoFar          | 35840       |
# | entloss                 | 0.0         |
# | entropy                 | 1.849828    |
# | explained_variance_t... | 0.728       |
# | meankl                  | 0.008365426 |
# | optimgain               | 0.04708791  |
# | surrgain                | 0.04708791  |
# -----------------------------------------
# ********** Iteration 35 ************
# Optimizing Policy...
# sampling
# done in 0.698 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0298          0
#          1     0.0279      0.122
#          2     0.0212      0.279
#          3      0.028      0.452
#          4     0.0227      0.754
#          5     0.0163       1.03
#          6     0.0148       1.25
#          7     0.0169       1.49
#          8    0.00823       1.77
#          9     0.0107       1.91
#         10    0.00458       2.12
# done in 0.022 seconds
# Expected: 0.060 Actual: 0.063
# Stepsize OK!
# vf
# done in 0.045 seconds
# -----------------------------------------
# | EpLenMean               | 630         |
# | EpRewMean               | -4.8        |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 61          |
# | TimeElapsed             | 33.6        |
# | TimestepsSoFar          | 36864       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8436762   |
# | explained_variance_t... | 0.621       |
# | meankl                  | 0.00846692  |
# | optimgain               | 0.062567234 |
# | surrgain                | 0.062567234 |
# -----------------------------------------
# ********** Iteration 36 ************
# Optimizing Policy...
# sampling
# done in 0.708 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0412          0
#          1      0.024      0.123
#          2     0.0177      0.231
#          3     0.0269      0.399
#          4     0.0231      0.542
#          5     0.0218      0.784
#          6     0.0174       1.02
#          7     0.0105       1.14
#          8    0.00786       1.39
#          9    0.00408       1.63
#         10    0.00573       1.88
# done in 0.022 seconds
# Expected: 0.057 Actual: 0.057
# Stepsize OK!
# vf
# done in 0.039 seconds
# -----------------------------------------
# | EpLenMean               | 635         |
# | EpRewMean               | -4.78       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 63          |
# | TimeElapsed             | 34.4        |
# | TimestepsSoFar          | 37888       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8507059   |
# | explained_variance_t... | 0.659       |
# | meankl                  | 0.008438369 |
# | optimgain               | 0.056601215 |
# | surrgain                | 0.056601215 |
# -----------------------------------------
# ********** Iteration 37 ************
# Optimizing Policy...
# sampling
# done in 0.676 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0289          0
#          1     0.0154      0.101
#          2     0.0195       0.27
#          3     0.0208      0.428
#          4     0.0297      0.799
#          5     0.0126       1.02
#          6    0.00721       1.21
#          7    0.00691       1.34
#          8     0.0107       1.56
#          9    0.00658       1.79
#         10    0.00731       1.92
# done in 0.021 seconds
# Expected: 0.055 Actual: 0.055
# Stepsize OK!
# vf
# done in 0.042 seconds
# -----------------------------------------
# | EpLenMean               | 643         |
# | EpRewMean               | -4.72       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 64          |
# | TimeElapsed             | 35.1        |
# | TimestepsSoFar          | 38912       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8488191   |
# | explained_variance_t... | 0.535       |
# | meankl                  | 0.009204008 |
# | optimgain               | 0.054847285 |
# | surrgain                | 0.054847285 |
# -----------------------------------------
# ********** Iteration 38 ************
# Optimizing Policy...
# sampling
# done in 0.680 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.059          0
#          1      0.013     0.0789
#          2     0.0207      0.199
#          3     0.0172       0.44
#          4     0.0213      0.643
#          5     0.0174      0.825
#          6     0.0142       1.16
#          7     0.0126        1.4
#          8    0.00834       1.63
#          9    0.00853       1.76
#         10    0.00655       1.99
# done in 0.020 seconds
# Expected: 0.056 Actual: 0.048
# Stepsize OK!
# vf
# done in 0.043 seconds
# -----------------------------------------
# | EpLenMean               | 650         |
# | EpRewMean               | -4.72       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 65          |
# | TimeElapsed             | 35.9        |
# | TimestepsSoFar          | 39936       |
# | entloss                 | 0.0         |
# | entropy                 | 1.8449339   |
# | explained_variance_t... | 0.633       |
# | meankl                  | 0.008237368 |
# ...
#       iter residual norm  soln norm
#          0     0.0603          0
#          1      0.066       0.11
#          2      0.048       0.22
#          3     0.0755      0.452
#          4      0.059      0.651
#          5     0.0572       1.01
#          6     0.0457       1.21
#          7     0.0283       1.41
#          8     0.0213       1.73
#          9     0.0154       2.02
#         10     0.0283        2.3
# done in 0.019 seconds
# Expected: 0.075 Actual: 0.083
# Stepsize OK!
# vf
# done in 0.039 seconds
# -----------------------------------------
# | EpLenMean               | 623         |
# | EpRewMean               | -4.9        |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 727         |
# | TimeElapsed             | 450         |
# | TimestepsSoFar          | 474112      |
# | entloss                 | 0.0         |
# | entropy                 | 1.1729627   |
# | explained_variance_t... | 0.648       |
# | meankl                  | 0.010502826 |
# | optimgain               | 0.08274415  |
# | surrgain                | 0.08274415  |
# -----------------------------------------
# ********** Iteration 463 ************
# Optimizing Policy...
# sampling
# Eval num_timesteps=474112, episode_reward=-4.90 +/- 0.30
# Episode length: 664.30 +/- 121.38
# done in 5.447 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0281          0
#          1     0.0353     0.0726
#          2     0.0285      0.224
#          3     0.0326      0.456
#          4     0.0462      0.654
#          5      0.023      0.877
#          6     0.0243       1.17
#          7     0.0321        1.5
#          8     0.0264       1.73
#          9     0.0164       2.12
#         10     0.0126       2.36
# done in 0.022 seconds
# Expected: 0.064 Actual: 0.061
# Stepsize OK!
# vf
# done in 0.040 seconds
# ------------------------------------------
# | EpLenMean               | 629          |
# | EpRewMean               | -4.88        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 729          |
# | TimeElapsed             | 456          |
# | TimestepsSoFar          | 475136       |
# | entloss                 | 0.0          |
# | entropy                 | 1.156682     |
# | explained_variance_t... | 0.655        |
# | meankl                  | 0.0140893925 |
# | optimgain               | 0.06104476   |
# | surrgain                | 0.06104476   |
# ------------------------------------------
# ********** Iteration 464 ************
# Optimizing Policy...
# sampling
# done in 0.685 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0855          0
#          1     0.0774       0.17
#          2      0.103      0.435
#          3     0.0521      0.681
#          4     0.0576      0.821
#          5     0.0838       1.17
#          6     0.0383       1.54
#          7     0.0689       1.79
#          8     0.0415       2.18
#          9     0.0371       2.57
#         10     0.0327       2.86
# done in 0.020 seconds
# Expected: 0.091 Actual: 0.074
# Stepsize OK!
# vf
# done in 0.041 seconds
# -----------------------------------------
# | EpLenMean               | 630         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 730         |
# | TimeElapsed             | 456         |
# | TimestepsSoFar          | 476160      |
# | entloss                 | 0.0         |
# | entropy                 | 1.1633408   |
# | explained_variance_t... | 0.767       |
# | meankl                  | 0.014585465 |
# | optimgain               | 0.074228525 |
# | surrgain                | 0.074228525 |
# -----------------------------------------
# ********** Iteration 465 ************
# Optimizing Policy...
# sampling
# done in 0.660 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0564          0
#          1     0.0391      0.105
#          2     0.0489      0.218
#          3     0.0298      0.448
#          4      0.036      0.597
#          5     0.0215      0.768
#          6     0.0165      0.945
#          7     0.0229       1.11
#          8     0.0125       1.41
#          9     0.0107       1.73
#         10     0.0128        1.9
# done in 0.021 seconds
# Expected: 0.063 Actual: 0.069
# Stepsize OK!
# vf
# done in 0.041 seconds
# -----------------------------------------
# | EpLenMean               | 633         |
# | EpRewMean               | -4.8        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 732         |
# | TimeElapsed             | 457         |
# | TimestepsSoFar          | 477184      |
# | entloss                 | 0.0         |
# | entropy                 | 1.1015062   |
# | explained_variance_t... | 0.695       |
# | meankl                  | 0.012088346 |
# | optimgain               | 0.06924739  |
# | surrgain                | 0.06924739  |
# -----------------------------------------
# ********** Iteration 466 ************
# Optimizing Policy...
# sampling
# done in 0.656 seconds
# computegrad
# done in 0.010 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0582          0
#          1     0.0417     0.0915
#          2      0.055      0.214
#          3     0.0444      0.515
#          4     0.0511      0.722
#          5     0.0217      0.904
#          6     0.0367       1.05
#          7     0.0281       1.31
#          8     0.0187       1.54
#          9     0.0226       1.78
#         10    0.00836       2.06
# done in 0.024 seconds
# Expected: 0.068 Actual: 0.071
# Stepsize OK!
# vf
# done in 0.039 seconds
# -----------------------------------------
# | EpLenMean               | 633         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 733         |
# | TimeElapsed             | 458         |
# | TimestepsSoFar          | 478208      |
# | entloss                 | 0.0         |
# | entropy                 | 1.1944672   |
# | explained_variance_t... | 0.787       |
# | meankl                  | 0.010594731 |
# | optimgain               | 0.071332216 |
# | surrgain                | 0.071332216 |
# -----------------------------------------
# ********** Iteration 467 ************
# Optimizing Policy...
# sampling
# done in 0.636 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0425          0
#          1     0.0473     0.0955
#          2     0.0619      0.262
#          3     0.0578      0.506
#          4     0.0431      0.752
#          5     0.0314      0.973
#          6     0.0303       1.22
#          7     0.0211       1.45
#          8     0.0386       1.65
#          9     0.0155       2.07
#         10     0.0185       2.39
# done in 0.021 seconds
# Expected: 0.072 Actual: 0.066
# Stepsize OK!
# vf
# done in 0.040 seconds
# ------------------------------------------
# | EpLenMean               | 638          |
# | EpRewMean               | -4.83        |
# | EpThisIter              | 1            |
# | EpisodesSoFar           | 734          |
# | TimeElapsed             | 459          |
# | TimestepsSoFar          | 479232       |
# | entloss                 | 0.0          |
# | entropy                 | 1.1220267    |
# | explained_variance_t... | 0.777        |
# | meankl                  | 0.0114081055 |
# | optimgain               | 0.06563313   |
# | surrgain                | 0.06563313   |
# ------------------------------------------
# ********** Iteration 468 ************
# Optimizing Policy...
# sampling
# done in 0.667 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0618          0
#          1     0.0449      0.117
#          2     0.0664      0.274
#          3     0.0555       0.49
#          4     0.0399      0.639
#          5     0.0418       0.84
#          6     0.0406      0.993
#          7      0.039        1.3
#          8     0.0185       1.55
#          9     0.0225       1.87
#         10     0.0153       2.13
# done in 0.021 seconds
# Expected: 0.071 Actual: 0.058
# Stepsize OK!
# vf
# done in 0.040 seconds
# ------------------------------------------
# | EpLenMean               | 630          |
# | EpRewMean               | -4.85        |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 736          |
# | TimeElapsed             | 459          |
# | TimestepsSoFar          | 480256       |
# | entloss                 | 0.0          |
# | entropy                 | 1.1697309    |
# | explained_variance_t... | 0.713        |
# | meankl                  | 0.0127246445 |
# | optimgain               | 0.05776811   |
# | surrgain                | 0.05776811   |
# ------------------------------------------
# ********** Iteration 469 ************
# Optimizing Policy...
# sampling
# done in 0.666 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0564          0
#          1      0.029      0.102
#          2     0.0398      0.195
#          3      0.037       0.38
#          4     0.0377       0.58
#          5      0.028      0.783
#          6     0.0257       0.97
#          7     0.0216       1.18
#          8     0.0243       1.42
#          9     0.0105        1.7
#         10      0.013       1.88
# done in 0.021 seconds
# Expected: 0.062 Actual: 0.060
# Stepsize OK!
# vf
# done in 0.042 seconds
# -----------------------------------------
# | EpLenMean               | 631         |
# | EpRewMean               | -4.85       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 738         |
# | TimeElapsed             | 460         |
# | TimestepsSoFar          | 481280      |
# | entloss                 | 0.0         |
# | entropy                 | 1.0756273   |
# | explained_variance_t... | 0.684       |
# | meankl                  | 0.010874882 |
# | optimgain               | 0.059869897 |
# | surrgain                | 0.059869897 |
# -----------------------------------------
# ********** Iteration 470 ************
# Optimizing Policy...
# sampling
# done in 0.707 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0317          0
#          1     0.0411      0.112
#          2     0.0594      0.274
#          3     0.0604      0.533
#          4     0.0504      0.846
#          5     0.0414       1.11
#          6      0.043       1.39
#          7     0.0431       1.68
#          8     0.0521        2.1
#          9     0.0196       2.45
#         10     0.0278        2.8
# done in 0.022 seconds
# Expected: 0.076 Actual: 0.121
# violated KL constraint. shrinking step.
# Expected: 0.076 Actual: 0.055
# Stepsize OK!
# vf
# done in 0.047 seconds
# -----------------------------------------
# | EpLenMean               | 632         |
# | EpRewMean               | -4.85       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 739         |
# | TimeElapsed             | 461         |
# | TimestepsSoFar          | 482304      |
# | entloss                 | 0.0         |
# | entropy                 | 1.114834    |
# | explained_variance_t... | 0.615       |
# | meankl                  | 0.004238615 |
# | optimgain               | 0.054526053 |
# | surrgain                | 0.054526053 |
# -----------------------------------------
# ********** Iteration 471 ************
# Optimizing Policy...
# sampling
# done in 0.744 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0329          0
#          1     0.0556     0.0829
#          2     0.0353      0.248
#          3     0.0604      0.445
#          4     0.0323      0.742
#          5     0.0552       0.96
#          6     0.0252       1.17
#          7       0.02       1.39
#          8     0.0172       1.75
#          9     0.0199       2.08
#         10    0.00995       2.37
# done in 0.021 seconds
# Expected: 0.069 Actual: 0.065
# Stepsize OK!
# vf
# done in 0.039 seconds
# -----------------------------------------
# | EpLenMean               | 638         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 741         |
# | TimeElapsed             | 462         |
# | TimestepsSoFar          | 483328      |
# | entloss                 | 0.0         |
# | entropy                 | 1.1909456   |
# | explained_variance_t... | 0.767       |
# | meankl                  | 0.01409691  |
# | optimgain               | 0.065110534 |
# | surrgain                | 0.065110534 |
# -----------------------------------------
# ********** Iteration 472 ************
# Optimizing Policy...
# sampling
# done in 0.727 seconds
# computegrad
# done in 0.013 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0372          0
#          1     0.0351      0.103
#          2     0.0794      0.521
#          3     0.0449      0.692
#          4     0.0467      0.933
#          5     0.0396       1.08
#          6     0.0362       1.32
#          7     0.0396       1.75
#          8       0.03       1.86
#          9     0.0385        2.2
#         10     0.0209       2.53
# done in 0.025 seconds
# Expected: 0.074 Actual: 0.070
# Stepsize OK!
# vf
# done in 0.048 seconds
# -----------------------------------------
# | EpLenMean               | 634         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 743         |
# | TimeElapsed             | 463         |
# | TimestepsSoFar          | 484352      |
# | entloss                 | 0.0         |
# | entropy                 | 1.223712    |
# | explained_variance_t... | 0.738       |
# | meankl                  | 0.013366258 |
# | optimgain               | 0.06999144  |
# | surrgain                | 0.06999144  |
# -----------------------------------------
# ********** Iteration 473 ************
# Optimizing Policy...
# sampling
# done in 0.812 seconds
# computegrad
# done in 0.009 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0658          0
#          1     0.0377     0.0933
#          2     0.0419      0.175
#          3     0.0744      0.442
#          4     0.0269      0.628
#          5     0.0306      0.821
#          6     0.0448      0.986
#          7     0.0323       1.25
#          8     0.0186       1.55
#          9     0.0152       1.91
#         10     0.0114        2.2
# done in 0.023 seconds
# Expected: 0.068 Actual: 0.063
# Stepsize OK!
# vf
# done in 0.048 seconds
# -----------------------------------------
# | EpLenMean               | 637         |
# | EpRewMean               | -4.83       |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 744         |
# | TimeElapsed             | 464         |
# | TimestepsSoFar          | 485376      |
# | entloss                 | 0.0         |
# | entropy                 | 1.2371371   |
# | explained_variance_t... | 0.571       |
# | meankl                  | 0.011241229 |
# | optimgain               | 0.06315234  |
# | surrgain                | 0.06315234  |
# -----------------------------------------
# ********** Iteration 474 ************
# Optimizing Policy...
# sampling
# done in 0.749 seconds
# computegrad
# done in 0.011 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0462          0
#          1     0.0605      0.102
#          2     0.0431      0.291
#          3     0.0628      0.461
#          4     0.0452      0.784
#          5     0.0468      0.959
#          6     0.0505       1.17
#          7     0.0383       1.61
#          8     0.0233       2.04
#          9       0.03       2.37
#         10     0.0181       2.71
# done in 0.025 seconds
# Expected: 0.077 Actual: 0.103
# Stepsize OK!
# vf
# done in 0.041 seconds
# -----------------------------------------
# | EpLenMean               | 642         |
# | EpRewMean               | -4.8        |
# | EpThisIter              | 1           |
# | EpisodesSoFar           | 745         |
# | TimeElapsed             | 464         |
# | TimestepsSoFar          | 486400      |
# | entloss                 | 0.0         |
# | entropy                 | 1.1935837   |
# | explained_variance_t... | 0.714       |
# | meankl                  | 0.013716961 |
# | optimgain               | 0.1026043   |
# | surrgain                | 0.1026043   |
# -----------------------------------------
# ********** Iteration 475 ************
# Optimizing Policy...
# sampling

# %%
video_filename = 'trpo.mp4'
record_game(
    model=trained_model['trpo'],
    env=gym.make("SlimeVolley-v0"),
    num_episodes=5,
    video_filename=video_filename
)
embed_mp4(video_filename)
