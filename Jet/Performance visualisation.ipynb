# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
plt.style.use("seaborn")

df = pd.read_csv("sb-a2c/progress.csv")
df.head()
# Out:
#    nupdates  policy_entropy  explained_variance  total_timesteps  value_loss  \
# 0         1        2.079419        -8530.828125                5    0.118992
# 1       100        2.079426         -761.288574              500    0.044773
# 2       200        2.079399         -415.271637             1000    0.028357
# 3       300        2.079408         -819.907593             1500    0.035744
# 4       400        2.079031        -6850.515625             2000    0.024545
#
#    fps
# 0   39
# 1  772
# 2  840
# 3  856
# 4  880

# %%
columns = ['policy_entropy', 'explained_variance', 'value_loss', 'fps']

nrow = 2
ncol = 2
fig, axes = plt.subplots(nrow, ncol)

i = 0
for r in range(nrow):
    for c in range(ncol):
        df[columns[i]].plot(ax=axes[r,c], title=columns[i])
        i += 1
