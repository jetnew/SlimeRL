# %%
from tensorflow.keras import backend as K
from tensorflow.keras import activations, initializers
from tensorflow.keras.layers import Layer

import tensorflow as tf
import tensorflow_probability as tfp

tfd = tfp.distributions
tfp.__version__
# Out:
# '0.8.0'

# %%
def bnn_extractor(flat_observations, net_arch, act_fun):
    """
    Constructs an variational layer that receives observations as an input and outputs a latent representation for the policy and
    a value network. The ``net_arch`` parameter allows to specify the amount and size of the hidden layers and how many
    of them are shared between the policy network and the value network. It is assumed to be a list with the following
    structure:
    1. An arbitrary length (zero allowed) number of integers each specifying the number of units in a shared layer.
       If the number of ints is zero, there will be no shared layers.
    2. An optional dict, to specify the following non-shared layers for the value network and the policy network.
       It is formatted like ``dict(vf=[<value layer sizes>], pi=[<policy layer sizes>])``.
       If it is missing any of the keys (pi or vf), no non-shared layers (empty list) is assumed.
    For example to construct a network with one shared layer of size 55 followed by two non-shared layers for the value
    network of size 255 and a single non-shared layer of size 128 for the policy network, the following layers_spec
    would be used: ``[55, dict(vf=[255, 255], pi=[128])]``. A simple shared network topology with two layers of size 128
    would be specified as [128, 128].
    :param flat_observations: (tf.Tensor) The observations to base policy and value function on.
    :param net_arch: ([int or dict]) The specification of the policy and value networks.
        See above for details on its formatting.
    :param act_fun: (tf function) The activation function to use for the networks.
    :return: (tf.Tensor, tf.Tensor) latent_policy, latent_value of the specified network.
        If all layers are shared, then ``latent_policy == latent_value``
    """
    latent = flat_observations
    policy_only_layers = []  # Layer sizes of the network that only belongs to the policy network
    value_only_layers = []  # Layer sizes of the network that only belongs to the value network
    kernel_divergence_fn=lambda q, p, _: tfp.distributions.kl_divergence(q, p)

    # Iterate through the shared layers and build the shared parts of the network
    for idx, layer in enumerate(net_arch):
        if isinstance(layer, int):  # Check that this is a shared layer
            layer_size = layer
#             latent = act_fun(linear(latent, "shared_fc{}".format(idx), layer_size, init_scale=np.sqrt(2)))
            latent = act_fun(tfp.layers.DenseFlipout(layer_size, activation = 'relu', kernel_divergence_fn=kernel_divergence_fn)(latent))
        else:
            assert isinstance(layer, dict), "Error: the net_arch list can only contain ints and dicts"
            if 'pi' in layer:
                assert isinstance(layer['pi'], list), "Error: net_arch[-1]['pi'] must contain a list of integers."
                policy_only_layers = layer['pi']

            if 'vf' in layer:
                assert isinstance(layer['vf'], list), "Error: net_arch[-1]['vf'] must contain a list of integers."
                value_only_layers = layer['vf']
            break  # From here on the network splits up in policy and value network

    # Build the non-shared part of the network
    latent_policy = latent
    latent_value = latent
    for idx, (pi_layer_size, vf_layer_size) in enumerate(zip_longest(policy_only_layers, value_only_layers)):
        if pi_layer_size is not None:
            assert isinstance(pi_layer_size, int), "Error: net_arch[-1]['pi'] must only contain integers."
#             latent_policy = act_fun(linear(latent_policy, "pi_fc{}".format(idx), pi_layer_size, init_scale=np.sqrt(2)))
            latent_policy = act_fun(tfp.layers.DenseFlipout(pi_layer_size, activation = 'relu', kernel_divergence_fn=kernel_divergence_fn)(latent))

        if vf_layer_size is not None:
            assert isinstance(vf_layer_size, int), "Error: net_arch[-1]['vf'] must only contain integers."
#             latent_value = act_fun(linear(latent_value, "vf_fc{}".format(idx), vf_layer_size, init_scale=np.sqrt(2)))
            latent_value = act_fun(tfp.layers.DenseFlipout(vf_layer_size, activation = 'relu', kernel_divergence_fn=kernel_divergence_fn)(latent))

    return latent_policy, latent_value

# %%
from stable_baselines.common.policies import ActorCriticPolicy, nature_cnn

class FeedForwardPolicy(ActorCriticPolicy):
    """
    Policy object that implements actor critic, using a feed forward neural network.
    :param sess: (TensorFlow session) The current TensorFlow session
    :param ob_space: (Gym Space) The observation space of the environment
    :param ac_space: (Gym Space) The action space of the environment
    :param n_env: (int) The number of environments to run
    :param n_steps: (int) The number of steps to run for each environment
    :param n_batch: (int) The number of batch to run (n_envs * n_steps)
    :param reuse: (bool) If the policy is reusable or not
    :param layers: ([int]) (deprecated, use net_arch instead) The size of the Neural network for the policy
        (if None, default to [64, 64])
    :param net_arch: (list) Specification of the actor-critic policy network architecture (see mlp_extractor
        documentation for details).
    :param act_fun: (tf.func) the activation function to use in the neural network.
    :param cnn_extractor: (function (TensorFlow Tensor, ``**kwargs``): (TensorFlow Tensor)) the CNN feature extraction
    :param feature_extraction: (str) The feature extraction type ("cnn" or "mlp")
    :param kwargs: (dict) Extra keyword arguments for the nature CNN feature extraction
    """

    def __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=False, layers=None, net_arch=None,
                 act_fun=tf.tanh, cnn_extractor=nature_cnn, feature_extraction="cnn", **kwargs):
        super(FeedForwardPolicy, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=reuse,
                                                scale=(feature_extraction == "cnn"))

        self._kwargs_check(feature_extraction, kwargs)

        if layers is not None:
            warnings.warn("Usage of the `layers` parameter is deprecated! Use net_arch instead "
                          "(it has a different semantics though).", DeprecationWarning)
            if net_arch is not None:
                warnings.warn("The new `net_arch` parameter overrides the deprecated `layers` parameter!",
                              DeprecationWarning)

        if net_arch is None:
            if layers is None:
                layers = [64, 64]
            net_arch = [dict(vf=layers, pi=layers)]

        with tf.variable_scope("model", reuse=reuse):
            if feature_extraction == "cnn":
                pi_latent = vf_latent = cnn_extractor(self.processed_obs, **kwargs)
            elif feature_extraction == "bnn":
                pi_latent, vf_latent = bnn_extractor(tf.layers.flatten(self.processed_obs), net_arch, act_fun)
            else:
                pi_latent, vf_latent = mlp_extractor(tf.layers.flatten(self.processed_obs), net_arch, act_fun)

            self._value_fn = linear(vf_latent, 'vf', 1)

            self._proba_distribution, self._policy, self.q_value = \
                self.pdtype.proba_distribution_from_latent(pi_latent, vf_latent, init_scale=0.01)

        self._setup_init()

    def step(self, obs, state=None, mask=None, deterministic=False):
        if deterministic:
            action, value, neglogp = self.sess.run([self.deterministic_action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        else:
            action, value, neglogp = self.sess.run([self.action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        return action, value, self.initial_state, neglogp

    def proba_step(self, obs, state=None, mask=None):
        return self.sess.run(self.policy_proba, {self.obs_ph: obs})

    def value(self, obs, state=None, mask=None):
        return self.sess.run(self.value_flat, {self.obs_ph: obs})
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
import warnings
from itertools import zip_longest
from abc import ABC, abstractmethod

import numpy as np
import tensorflow as tf
from gym.spaces import Discrete

from stable_baselines.common.tf_util import batch_to_seq, seq_to_batch
from stable_baselines.common.tf_layers import conv, linear, conv_to_fc, lstm
from stable_baselines.common.distributions import make_proba_dist_type, CategoricalProbabilityDistribution, \
    MultiCategoricalProbabilityDistribution, DiagGaussianProbabilityDistribution, BernoulliProbabilityDistribution
from stable_baselines.common.input import observation_input
from stable_baselines.common.policies import nature_cnn

# %%
class BnnPolicy(FeedForwardPolicy):
    """
    Policy object that implements actor critic, using a Bayesian neural net (2 layers of 64)
    :param sess: (TensorFlow session) The current TensorFlow session
    :param ob_space: (Gym Space) The observation space of the environment
    :param ac_space: (Gym Space) The action space of the environment
    :param n_env: (int) The number of environments to run
    :param n_steps: (int) The number of steps to run for each environment
    :param n_batch: (int) The number of batch to run (n_envs * n_steps)
    :param reuse: (bool) If the policy is reusable or not
    :param _kwargs: (dict) Extra keyword arguments for the nature CNN feature extraction
    """

    def __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=False, **_kwargs):
        super(BnnPolicy, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse,
                                        feature_extraction="bnn", **_kwargs)

# %% [markdown]
# # DNN Cartpole

# %%
import os
import gym

from stable_baselines.ppo1 import PPO1
from stable_baselines.common.policies import MlpPolicy
from stable_baselines import logger
from stable_baselines.common.callbacks import EvalCallback

NUM_TIMESTEPS = int(1e4)
SEED = 722
EVAL_FREQ = 250000
EVAL_EPISODES = 10  # was 1000

LOGDIR = "dnn_acrobot" # moved to zoo afterwards.
logger.configure(folder=LOGDIR)

env = gym.make("Acrobot-v1")
env.seed(SEED)
# Out:
# Logging to dnn_acrobot
# [722]

# %%
# take mujoco hyperparams (but doubled timesteps_per_actorbatch to cover more steps.)
dnn = PPO1(MlpPolicy, env, timesteps_per_actorbatch=4096, clip_param=0.2, entcoeff=0.0, optim_epochs=10,
                 optim_stepsize=3e-4, optim_batchsize=64, gamma=0.99, lam=0.95, schedule='linear', verbose=2)

eval_callback = EvalCallback(env, best_model_save_path=LOGDIR, log_path=LOGDIR, eval_freq=EVAL_FREQ, n_eval_episodes=EVAL_EPISODES)

dnn.learn(total_timesteps=NUM_TIMESTEPS, callback=eval_callback)

dnn.save(os.path.join(LOGDIR, "final_model")) # probably never get to this point.

env.close()
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Users/Aakanksha 1/.local/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/ppo1/pposgd_simple.py:152: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/ppo1/pposgd_simple.py:162: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/ppo1/pposgd_simple.py:190: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /Users/Aakanksha 1/.local/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<AcrobotEnv<Acrobot-v1>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fc37901f2d0>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00051 |       0.00000 |     240.78682 |       0.00021 |       1.09840
#      -0.00028 |       0.00000 |     178.88135 |       0.00060 |       1.09799
#      -0.00096 |       0.00000 |     112.32079 |       0.00164 |       1.09695
#      -0.00157 |       0.00000 |      64.52588 |       0.00269 |       1.09588
#      -0.00190 |       0.00000 |      37.71918 |       0.00356 |       1.09502
#      -0.00212 |       0.00000 |      22.85038 |       0.00337 |       1.09522
#      -0.00244 |       0.00000 |      14.43047 |       0.00381 |       1.09480
#      -0.00302 |       0.00000 |       9.68169 |       0.00420 |       1.09440
#      -0.00325 |       0.00000 |       7.02277 |       0.00432 |       1.09429
#      -0.00325 |       0.00000 |       5.57533 |       0.00461 |       1.09402
# Evaluating losses...
#      -0.00424 |       0.00000 |       5.10339 |       0.00407 |       1.09453
# -----------------------------------
# | EpLenMean       | 500           |
# | EpRewMean       | -500          |
# | EpThisIter      | 8             |
# | EpisodesSoFar   | 8             |
# | TimeElapsed     | 3.63          |
# | TimestepsSoFar  | 4096          |
# | ev_tdlam_before | -0.0238       |
# | loss_ent        | 1.0945256     |
# | loss_kl         | 0.0040698466  |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0042374707 |
# | loss_vf_loss    | 5.103388      |
# -----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00174 |       0.00000 |     169.07555 |       0.00054 |       1.09238
#      -0.00442 |       0.00000 |     129.23558 |       0.00241 |       1.08801
#      -0.00484 |       0.00000 |     103.14822 |       0.00258 |       1.08776
#      -0.00508 |       0.00000 |      84.36057 |       0.00294 |       1.08696
#      -0.00523 |       0.00000 |      70.01578 |       0.00300 |       1.08683
#      -0.00519 |       0.00000 |      58.77244 |       0.00282 |       1.08678
#      -0.00528 |       0.00000 |      49.79979 |       0.00316 |       1.08633
#      -0.00537 |       0.00000 |      42.55746 |       0.00326 |       1.08658
#      -0.00552 |       0.00000 |      36.71405 |       0.00326 |       1.08597
#      -0.00571 |       0.00000 |      31.99817 |       0.00344 |       1.08609
# Evaluating losses...
#      -0.00603 |       0.00000 |      29.87722 |       0.00349 |       1.08566
# ----------------------------------
# | EpLenMean       | 500          |
# | EpRewMean       | -500         |
# | EpThisIter      | 8            |
# | EpisodesSoFar   | 16           |
# | TimeElapsed     | 6.93         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.0494       |
# | loss_ent        | 1.0856624    |
# | loss_kl         | 0.0034917889 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.006033582 |
# | loss_vf_loss    | 29.877224    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00024 |       0.00000 |     148.55746 |      6.52e-05 |       1.08544
#      -0.00096 |       0.00000 |     140.29477 |       0.00017 |       1.08443
#      -0.00111 |       0.00000 |     132.87840 |       0.00020 |       1.08427
#      -0.00124 |       0.00000 |     126.20551 |       0.00018 |       1.08415
#      -0.00120 |       0.00000 |     120.12234 |       0.00022 |       1.08369
#      -0.00131 |       0.00000 |     114.51901 |       0.00022 |       1.08411
#      -0.00140 |       0.00000 |     109.33121 |       0.00026 |       1.08372
#      -0.00154 |       0.00000 |     104.48118 |       0.00024 |       1.08419
#      -0.00150 |       0.00000 |      99.94379 |       0.00026 |       1.08350
#      -0.00167 |       0.00000 |      95.67399 |       0.00027 |       1.08390
# Evaluating losses...
#      -0.00177 |       0.00000 |      93.59007 |       0.00025 |       1.08384
# -----------------------------------
# | EpLenMean       | 493           |
# | EpRewMean       | -493          |
# | EpThisIter      | 8             |
# | EpisodesSoFar   | 24            |
# | TimeElapsed     | 10.1          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | 0.158         |
# | loss_ent        | 1.0838366     |
# | loss_kl         | 0.00024615196 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0017651675 |
# | loss_vf_loss    | 93.590065     |
# -----------------------------------

# %% [markdown]
# # BNN Cartpole

# %%
NUM_TIMESTEPS = int(1e4)
SEED = 722
EVAL_FREQ = 250000
EVAL_EPISODES = 10  # was 1000

LOGDIR = "bnn_acrobot" # moved to zoo afterwards.
logger.configure(folder=LOGDIR)

env = gym.make("Acrobot-v1")
env.seed(SEED)
# Out:
# Logging to bnn_acrobot
# [722]

# %%
# take mujoco hyperparams (but doubled timesteps_per_actorbatch to cover more steps.)
bnn = PPO1(BnnPolicy, env, timesteps_per_actorbatch=4096, clip_param=0.2, entcoeff=0.0, optim_epochs=10,
                 optim_stepsize=3e-4, optim_batchsize=64, gamma=0.99, lam=0.95, schedule='linear', verbose=2)

eval_callback = EvalCallback(env, best_model_save_path=LOGDIR, log_path=LOGDIR, eval_freq=EVAL_FREQ, n_eval_episodes=EVAL_EPISODES)

bnn.learn(total_timesteps=NUM_TIMESTEPS, callback=eval_callback)

bnn.save(os.path.join(LOGDIR, "final_model")) # probably never get to this point.

env.close()
# Out:
# WARNING:tensorflow:From /Users/Aakanksha 1/.local/lib/python3.7/site-packages/tensorflow_probability/python/layers/util.py:104: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /Users/Aakanksha 1/.local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<AcrobotEnv<Acrobot-v1>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fc35a362450>
#   "{} != {}".format(self.training_env, self.eval_env))

# %% [markdown]
# # Performance

# %%
from stable_baselines.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(dnn, dnn.get_env(), n_eval_episodes=1000)
print(f"DNN - Mean reward: {mean_reward}, Std reward: {std_reward}")

mean_reward, std_reward = evaluate_policy(bnn, bnn.get_env(), n_eval_episodes=1000)
print(f"BNN - Mean reward: {mean_reward}, Std reward: {std_reward}")
# Out:
# DNN - Mean reward: 187.59, Std reward: 20.69627744305724
# BNN - Mean reward: 172.414, Std reward: 27.614210182440488

# %%
from stable_baselines.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(dnn, dnn.get_env(), n_eval_episodes=1000)
print(f"DNN - Mean reward: {mean_reward}, Std reward: {std_reward}")

mean_reward, std_reward = evaluate_policy(bnn, bnn.get_env(), n_eval_episodes=1000)
print(f"BNN - Mean reward: {mean_reward}, Std reward: {std_reward}")
# Out:
# DNN - Mean reward: 175.151, Std reward: 38.99818199608797
# BNN - Mean reward: 164.046, Std reward: 45.66565321989822

# %%
from stable_baselines.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(dnn, dnn.get_env(), n_eval_episodes=1000)
print(f"DNN - Mean reward: {mean_reward}, Std reward: {std_reward}")

mean_reward, std_reward = evaluate_policy(bnn, bnn.get_env(), n_eval_episodes=1000)
print(f"BNN - Mean reward: {mean_reward}, Std reward: {std_reward}")
# Out:
# DNN - Mean reward: 156.935, Std reward: 48.66798511341928
# BNN - Mean reward: 189.304, Std reward: 18.416991719605022

# %%
from stable_baselines.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(dnn, dnn.get_env(), n_eval_episodes=1000)
print(f"DNN - Mean reward: {mean_reward}, Std reward: {std_reward}")

mean_reward, std_reward = evaluate_policy(bnn, bnn.get_env(), n_eval_episodes=1000)
print(f"BNN - Mean reward: {mean_reward}, Std reward: {std_reward}")
# Out:
# DNN - Mean reward: 161.503, Std reward: 47.323144348193935
# BNN - Mean reward: 178.989, Std reward: 32.992982268961384

# %% [markdown]
# # Evalutaion

# %% [markdown]
# There are a few possible ways we can take this:
# 1. Small number of iterations on CartPole, to see which model performs better with less data.
# 2. Run experiment on Acrobot, to hopefully see BNN > DNN.
# 3. Hide 1 out of every N frames from the learning agent (self-play or single-agent), to hopefully see BNN > DNN.
#
# For all of the above, run a hundred different initialisations using different random seeds, and evaluate using at least 1K episodes (the episodes have extremely high variance even with the same random seed)

# %%
import pandas as pd

#To store experiment results
df = pd.DataFrame(columns = ['Seed', 'BNN reward', 'BNN std', 'DNN reward', 'DNN std']) 

df.head()
# Out:
# Empty DataFrame
# Columns: [Seed, BNN reward, BNN std, DNN reward, DNN std]
# Index: []

# %%
#Evaluation method one

import os
import gym

from stable_baselines.ppo1 import PPO1
from stable_baselines.common.policies import MlpPolicy
from stable_baselines import logger
from stable_baselines.common.callbacks import EvalCallback
from stable_baselines.common.evaluation import evaluate_policy

NUM_TIMESTEPS = int(1e4)
SEED = 722
EVAL_FREQ = 250000
EVAL_EPISODES = 10  # was 1000

for SEED in range (600, 701):
    LOGDIR = "dnn_cartpole" # moved to zoo afterwards.
    logger.configure(folder=LOGDIR)
    
    env = gym.make("CartPole-v0")
    env.seed(SEED)

    # take mujoco hyperparams (but doubled timesteps_per_actorbatch to cover more steps.)
    dnn = PPO1(MlpPolicy, env, timesteps_per_actorbatch=4096, clip_param=0.2, entcoeff=0.0, optim_epochs=10,
                 optim_stepsize=3e-4, optim_batchsize=64, gamma=0.99, lam=0.95, schedule='linear', verbose=2)

    eval_callback = EvalCallback(env, best_model_save_path=LOGDIR, log_path=LOGDIR, eval_freq=EVAL_FREQ, n_eval_episodes=EVAL_EPISODES)

    dnn.learn(total_timesteps=NUM_TIMESTEPS, callback=eval_callback)

    dnn.save(os.path.join(LOGDIR, "final_model")) # probably never get to this point.

    env.close()
    
    LOGDIR = "bnn_cartpole" # moved to zoo afterwards.
    logger.configure(folder=LOGDIR)

    env = gym.make("CartPole-v0")
    env.seed(SEED)
    
    # take mujoco hyperparams (but doubled timesteps_per_actorbatch to cover more steps.)
    bnn = PPO1(BnnPolicy, env, timesteps_per_actorbatch=4096, clip_param=0.2, entcoeff=0.0, optim_epochs=10,
                 optim_stepsize=3e-4, optim_batchsize=64, gamma=0.99, lam=0.95, schedule='linear', verbose=2)

    eval_callback = EvalCallback(env, best_model_save_path=LOGDIR, log_path=LOGDIR, eval_freq=EVAL_FREQ, n_eval_episodes=EVAL_EPISODES)

    bnn.learn(total_timesteps=NUM_TIMESTEPS, callback=eval_callback)

    bnn.save(os.path.join(LOGDIR, "final_model")) # probably never get to this point.

    env.close()
    
    mean_rewardDNN, std_rewardDNN = evaluate_policy(dnn, dnn.get_env(), n_eval_episodes=1000)
    print(f"DNN - Mean reward: {mean_rewardDNN}, Std reward: {std_rewardDNN}")

    mean_rewardBNN, std_rewardBNN = evaluate_policy(bnn, bnn.get_env(), n_eval_episodes=1000)
    print(f"BNN - Mean reward: {mean_rewardBNN}, Std reward: {std_rewardBNN}")
    
    data = {
    "Seed" : SEED,
    "BNN reward" : mean_rewardBNN,
    "BNN std" : std_rewardBNN,
    "DNN reward" : mean_rewardDNN,
    "DNN std" : std_rewardDNN
    }

    df = df.append(data, ignore_index=True)
# Out:
# Logging to dnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdfece47f90>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.01104 |       0.00000 |      83.31959 |       0.00455 |       0.68846
#      -0.01737 |       0.00000 |      70.39660 |       0.00789 |       0.68506
#      -0.01893 |       0.00000 |      44.48908 |       0.00881 |       0.68414
#      -0.02156 |       0.00000 |      22.42776 |       0.00901 |       0.68393
#      -0.02429 |       0.00000 |      15.77996 |       0.01042 |       0.68252
#      -0.02641 |       0.00000 |      14.44719 |       0.01168 |       0.68127
#      -0.02701 |       0.00000 |      13.38486 |       0.01305 |       0.67991
#      -0.02805 |       0.00000 |      12.24819 |       0.01337 |       0.67960
#      -0.02847 |       0.00000 |      11.23798 |       0.01376 |       0.67921
#      -0.02903 |       0.00000 |      10.48966 |       0.01386 |       0.67911
# Evaluating losses...
#      -0.02881 |       0.00000 |      10.17848 |       0.01603 |       0.67697
# ----------------------------------
# | EpLenMean       | 20.7         |
# | EpRewMean       | 20.7         |
# | EpThisIter      | 189          |
# | EpisodesSoFar   | 189          |
# | TimeElapsed     | 2.57         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.0034       |
# | loss_ent        | 0.67696905   |
# | loss_kl         | 0.016028633  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.028806917 |
# | loss_vf_loss    | 10.178475    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00713 |       0.00000 |      55.18892 |       0.00202 |       0.66737
#      -0.01252 |       0.00000 |      39.75476 |       0.00277 |       0.66364
#      -0.01388 |       0.00000 |      37.09406 |       0.00304 |       0.66292
#      -0.01457 |       0.00000 |      35.66897 |       0.00316 |       0.66267
#      -0.01499 |       0.00000 |      34.54265 |       0.00337 |       0.66206
#      -0.01542 |       0.00000 |      33.54132 |       0.00347 |       0.66186
#      -0.01566 |       0.00000 |      32.64967 |       0.00362 |       0.66159
#      -0.01608 |       0.00000 |      31.83204 |       0.00381 |       0.66114
#      -0.01622 |       0.00000 |      31.04836 |       0.00381 |       0.66131
#      -0.01660 |       0.00000 |      30.30862 |       0.00393 |       0.66107
# Evaluating losses...
#      -0.01680 |       0.00000 |      29.89725 |       0.00376 |       0.66160
# ----------------------------------
# | EpLenMean       | 32.2         |
# | EpRewMean       | 32.2         |
# | EpThisIter      | 125          |
# | EpisodesSoFar   | 314          |
# | TimeElapsed     | 4.9          |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.177        |
# | loss_ent        | 0.66159606   |
# | loss_kl         | 0.0037571893 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.016797718 |
# | loss_vf_loss    | 29.89725     |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00318 |       0.00000 |      79.38815 |       0.00024 |       0.66010
#      -0.00442 |       0.00000 |      69.66245 |       0.00025 |       0.65973
#      -0.00480 |       0.00000 |      64.81744 |       0.00024 |       0.65977
#      -0.00501 |       0.00000 |      61.95152 |       0.00026 |       0.65949
#      -0.00508 |       0.00000 |      59.91744 |       0.00029 |       0.65919
#      -0.00518 |       0.00000 |      58.34294 |       0.00030 |       0.65907
#      -0.00522 |       0.00000 |      57.04769 |       0.00032 |       0.65894
#      -0.00527 |       0.00000 |      55.90359 |       0.00033 |       0.65881
#      -0.00533 |       0.00000 |      54.89290 |       0.00034 |       0.65886
#      -0.00536 |       0.00000 |      53.96482 |       0.00036 |       0.65862
# Evaluating losses...
#      -0.00544 |       0.00000 |      53.51744 |       0.00033 |       0.65886
# -----------------------------------
# | EpLenMean       | 45.7          |
# | EpRewMean       | 45.7          |
# | EpThisIter      | 84            |
# | EpisodesSoFar   | 398           |
# | TimeElapsed     | 7.22          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | 0.276         |
# | loss_ent        | 0.6588648     |
# | loss_kl         | 0.00033251263 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.005438705  |
# | loss_vf_loss    | 53.51744      |
# -----------------------------------
# Logging to bnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdfee5b4090>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00168 |       0.00000 |      93.04918 |       0.00010 |       0.69305
#      -0.00627 |       0.00000 |      90.33788 |       0.00093 |       0.69221
#      -0.01293 |       0.00000 |      87.07071 |       0.00436 |       0.68881
#      -0.01600 |       0.00000 |      83.06079 |       0.00770 |       0.68553
#      -0.01655 |       0.00000 |      78.25071 |       0.00884 |       0.68440
#      -0.01734 |       0.00000 |      72.83126 |       0.00866 |       0.68458
#      -0.01846 |       0.00000 |      67.07480 |       0.00882 |       0.68442
#      -0.01998 |       0.00000 |      61.22139 |       0.00917 |       0.68406
#      -0.02124 |       0.00000 |      55.44053 |       0.00942 |       0.68382
#      -0.02289 |       0.00000 |      49.86128 |       0.01027 |       0.68297
# Evaluating losses...
#      -0.02381 |       0.00000 |      47.13252 |       0.01006 |       0.68318
# ----------------------------------
# | EpLenMean       | 24.7         |
# | EpRewMean       | 24.7         |
# | EpThisIter      | 179          |
# | EpisodesSoFar   | 179          |
# | TimeElapsed     | 3.2          |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.00331     |
# | loss_ent        | 0.68317884   |
# | loss_kl         | 0.01005963   |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.023810653 |
# | loss_vf_loss    | 47.13252     |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00203 |       0.00000 |      86.70354 |       0.00032 |       0.68204
#      -0.00587 |       0.00000 |      80.42445 |       0.00153 |       0.67633
#      -0.00669 |       0.00000 |      74.66681 |       0.00203 |       0.67468
#      -0.00738 |       0.00000 |      69.34524 |       0.00201 |       0.67472
#      -0.00794 |       0.00000 |      64.44312 |       0.00241 |       0.67363
#      -0.00896 |       0.00000 |      59.90862 |       0.00240 |       0.67372
#      -0.00973 |       0.00000 |      55.70734 |       0.00256 |       0.67318
#      -0.00963 |       0.00000 |      51.85219 |       0.00285 |       0.67241
#      -0.01031 |       0.00000 |      48.30402 |       0.00267 |       0.67301
#      -0.01043 |       0.00000 |      45.08305 |       0.00271 |       0.67294
# Evaluating losses...
#      -0.01080 |       0.00000 |      43.54840 |       0.00270 |       0.67309
# ----------------------------------
# | EpLenMean       | 30.3         |
# | EpRewMean       | 30.3         |
# | EpThisIter      | 142          |
# | EpisodesSoFar   | 321          |
# | TimeElapsed     | 6            |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | -0.0902      |
# | loss_ent        | 0.6730939    |
# | loss_kl         | 0.0026981055 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.010795088 |
# | loss_vf_loss    | 43.5484      |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      8.27e-05 |       0.00000 |     100.45496 |       0.00019 |       0.67442
#      -0.00118 |       0.00000 |      97.67541 |       0.00028 |       0.67274
#      -0.00081 |       0.00000 |      95.15701 |       0.00034 |       0.67204
#      -0.00104 |       0.00000 |      92.76085 |       0.00035 |       0.67202
#      -0.00122 |       0.00000 |      90.55962 |       0.00035 |       0.67194
#      -0.00198 |       0.00000 |      88.47617 |       0.00032 |       0.67210
#      -0.00153 |       0.00000 |      86.41543 |       0.00036 |       0.67208
#      -0.00143 |       0.00000 |      84.48283 |       0.00036 |       0.67193
#      -0.00167 |       0.00000 |      82.64923 |       0.00036 |       0.67183
#      -0.00145 |       0.00000 |      80.86151 |       0.00038 |       0.67158
# Evaluating losses...
#      -0.00167 |       0.00000 |      80.03188 |       0.00037 |       0.67179
# -----------------------------------
# | EpLenMean       | 37.9          |
# | EpRewMean       | 37.9          |
# | EpThisIter      | 111           |
# | EpisodesSoFar   | 432           |
# | TimeElapsed     | 8.73          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | -0.0263       |
# | loss_ent        | 0.6717941     |
# | loss_kl         | 0.00037262036 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0016723657 |
# | loss_vf_loss    | 80.031876     |
# -----------------------------------
# DNN - Mean reward: 173.827, Std reward: 39.67771504257774
# BNN - Mean reward: 174.573, Std reward: 38.308180209976044
# Logging to dnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdff1d5f210>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00831 |       0.00000 |      79.21246 |       0.00347 |       0.68986
#      -0.01438 |       0.00000 |      66.12856 |       0.00804 |       0.68546
#      -0.01619 |       0.00000 |      40.38298 |       0.00849 |       0.68502
#      -0.01907 |       0.00000 |      20.21524 |       0.00905 |       0.68447
#      -0.02272 |       0.00000 |      14.85998 |       0.01055 |       0.68300
#      -0.02603 |       0.00000 |      13.72186 |       0.01193 |       0.68165
#      -0.02789 |       0.00000 |      12.59174 |       0.01298 |       0.68062
#      -0.02908 |       0.00000 |      11.32942 |       0.01344 |       0.68016
#      -0.02968 |       0.00000 |      10.20894 |       0.01349 |       0.68011
#      -0.02997 |       0.00000 |       9.40086 |       0.01393 |       0.67968
# Evaluating losses...
#      -0.03028 |       0.00000 |       9.09371 |       0.01264 |       0.68092
# ----------------------------------
# | EpLenMean       | 19.7         |
# | EpRewMean       | 19.7         |
# | EpThisIter      | 196          |
# | EpisodesSoFar   | 196          |
# | TimeElapsed     | 2.44         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.000337     |
# | loss_ent        | 0.680923     |
# | loss_kl         | 0.012637951  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.030281045 |
# | loss_vf_loss    | 9.093708     |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.01118 |       0.00000 |      52.39930 |       0.00258 |       0.66978
#      -0.01658 |       0.00000 |      36.81685 |       0.00334 |       0.66634
#      -0.01800 |       0.00000 |      33.96211 |       0.00367 |       0.66527
#      -0.01853 |       0.00000 |      32.46222 |       0.00395 |       0.66451
#      -0.01892 |       0.00000 |      31.36219 |       0.00421 |       0.66398
#      -0.01918 |       0.00000 |      30.52295 |       0.00448 |       0.66338
#      -0.01949 |       0.00000 |      29.83998 |       0.00459 |       0.66319
#      -0.01964 |       0.00000 |      29.23461 |       0.00464 |       0.66313
#      -0.01957 |       0.00000 |      28.68425 |       0.00497 |       0.66236
#      -0.01986 |       0.00000 |      28.15060 |       0.00491 |       0.66266
# Evaluating losses...
#      -0.02013 |       0.00000 |      27.88742 |       0.00484 |       0.66288
# ----------------------------------
# | EpLenMean       | 32.6         |
# | EpRewMean       | 32.6         |
# | EpThisIter      | 124          |
# | EpisodesSoFar   | 320          |
# | TimeElapsed     | 4.54         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.225        |
# | loss_ent        | 0.66287583   |
# | loss_kl         | 0.0048411805 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.020134531 |
# | loss_vf_loss    | 27.887419    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00386 |       0.00000 |      73.38304 |       0.00028 |       0.65853
#      -0.00515 |       0.00000 |      65.64140 |       0.00026 |       0.65824
#      -0.00555 |       0.00000 |      61.85469 |       0.00028 |       0.65789
#      -0.00564 |       0.00000 |      59.60769 |       0.00031 |       0.65757
#      -0.00573 |       0.00000 |      58.03958 |       0.00033 |       0.65746
#      -0.00577 |       0.00000 |      56.82070 |       0.00033 |       0.65747
#      -0.00578 |       0.00000 |      55.80406 |       0.00037 |       0.65715
#      -0.00573 |       0.00000 |      54.92009 |       0.00039 |       0.65687
#      -0.00588 |       0.00000 |      54.12560 |       0.00038 |       0.65697
#      -0.00593 |       0.00000 |      53.40747 |       0.00039 |       0.65693
# Evaluating losses...
#      -0.00596 |       0.00000 |      53.04358 |       0.00037 |       0.65719
# ----------------------------------
# | EpLenMean       | 43.4         |
# | EpRewMean       | 43.4         |
# | EpThisIter      | 94           |
# | EpisodesSoFar   | 414          |
# | TimeElapsed     | 6.65         |
# | TimestepsSoFar  | 12288        |
# | ev_tdlam_before | 0.293        |
# | loss_ent        | 0.65718883   |
# | loss_kl         | 0.000367616  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.005961725 |
# | loss_vf_loss    | 53.043583    |
# ----------------------------------
# Logging to bnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdfef059dd0>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00132 |       0.00000 |      87.21719 |       0.00013 |       0.69301
#      -0.00562 |       0.00000 |      84.53976 |       0.00078 |       0.69235
#      -0.01187 |       0.00000 |      81.48814 |       0.00370 |       0.68942
#      -0.01646 |       0.00000 |      77.90315 |       0.00719 |       0.68598
#      -0.01748 |       0.00000 |      73.66091 |       0.00859 |       0.68460
#      -0.01823 |       0.00000 |      68.84760 |       0.00906 |       0.68413
#      -0.01973 |       0.00000 |      63.66901 |       0.00900 |       0.68419
#      -0.02108 |       0.00000 |      58.23838 |       0.00932 |       0.68387
#      -0.02271 |       0.00000 |      52.80296 |       0.01061 |       0.68259
#      -0.02435 |       0.00000 |      47.55459 |       0.01050 |       0.68270
# Evaluating losses...
#      -0.02501 |       0.00000 |      44.98935 |       0.01096 |       0.68224
# ----------------------------------
# | EpLenMean       | 21.6         |
# | EpRewMean       | 21.6         |
# | EpThisIter      | 188          |
# | EpisodesSoFar   | 188          |
# | TimeElapsed     | 2.9          |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.00561      |
# | loss_ent        | 0.6822368    |
# | loss_kl         | 0.010960842  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.025013197 |
# | loss_vf_loss    | 44.989353    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00322 |       0.00000 |      82.19707 |       0.00045 |       0.68044
#      -0.00739 |       0.00000 |      76.38984 |       0.00187 |       0.67398
#      -0.00807 |       0.00000 |      71.05260 |       0.00219 |       0.67294
#      -0.00886 |       0.00000 |      66.15223 |       0.00239 |       0.67227
#      -0.00989 |       0.00000 |      61.65812 |       0.00233 |       0.67244
#      -0.00980 |       0.00000 |      57.45799 |       0.00253 |       0.67200
#      -0.01076 |       0.00000 |      53.59218 |       0.00258 |       0.67187
#      -0.01107 |       0.00000 |      50.00822 |       0.00287 |       0.67099
#      -0.01097 |       0.00000 |      46.75813 |       0.00275 |       0.67151
#      -0.01133 |       0.00000 |      43.68704 |       0.00302 |       0.67070
# Evaluating losses...
#      -0.01190 |       0.00000 |      42.25114 |       0.00286 |       0.67125
# ----------------------------------
# | EpLenMean       | 26.4         |
# | EpRewMean       | 26.4         |
# | EpThisIter      | 152          |
# | EpisodesSoFar   | 340          |
# | TimeElapsed     | 5.37         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | -0.0735      |
# | loss_ent        | 0.6712535    |
# | loss_kl         | 0.0028562737 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.01190386  |
# | loss_vf_loss    | 42.251144    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      7.03e-05 |       0.00000 |      82.36281 |       0.00015 |       0.67316
#      -0.00061 |       0.00000 |      80.32256 |       0.00020 |       0.67184
#      -0.00079 |       0.00000 |      78.31359 |       0.00024 |       0.67134
#      -0.00073 |       0.00000 |      76.48978 |       0.00026 |       0.67109
#      -0.00082 |       0.00000 |      74.76931 |       0.00030 |       0.67082
#      -0.00132 |       0.00000 |      73.09424 |       0.00029 |       0.67075
#      -0.00049 |       0.00000 |      71.57285 |       0.00028 |       0.67101
#      -0.00103 |       0.00000 |      70.05103 |       0.00029 |       0.67088
#      -0.00110 |       0.00000 |      68.61980 |       0.00033 |       0.67053
#      -0.00124 |       0.00000 |      67.16623 |       0.00029 |       0.67096
# Evaluating losses...
#      -0.00104 |       0.00000 |      66.47026 |       0.00029 |       0.67089
# -----------------------------------
# | EpLenMean       | 32.3          |
# | EpRewMean       | 32.3          |
# | EpThisIter      | 128           |
# | EpisodesSoFar   | 468           |
# | TimeElapsed     | 7.85          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | -0.00587      |
# | loss_ent        | 0.670895      |
# | loss_kl         | 0.00029304888 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0010446768 |
# | loss_vf_loss    | 66.47026      |
# -----------------------------------
# DNN - Mean reward: 174.281, Std reward: 37.20446262211026
# BNN - Mean reward: 158.712, Std reward: 54.098253724126806
# Logging to dnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdff184f890>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00671 |       0.00000 |      94.10288 |       0.00339 |       0.68969
#      -0.01539 |       0.00000 |      80.57233 |       0.00742 |       0.68564
#      -0.01633 |       0.00000 |      52.34605 |       0.00850 |       0.68456
#      -0.01884 |       0.00000 |      26.87642 |       0.00842 |       0.68463
#      -0.02208 |       0.00000 |      18.23467 |       0.00916 |       0.68389
#      -0.02509 |       0.00000 |      16.41891 |       0.01111 |       0.68196
#      -0.02714 |       0.00000 |      15.13486 |       0.01211 |       0.68097
#      -0.02833 |       0.00000 |      13.73058 |       0.01296 |       0.68013
#      -0.02925 |       0.00000 |      12.51557 |       0.01339 |       0.67972
#      -0.02970 |       0.00000 |      11.65894 |       0.01338 |       0.67972
# Evaluating losses...
#      -0.03014 |       0.00000 |      11.33321 |       0.01316 |       0.67995
# ----------------------------------
# | EpLenMean       | 23.3         |
# | EpRewMean       | 23.3         |
# | EpThisIter      | 175          |
# | EpisodesSoFar   | 175          |
# | TimeElapsed     | 2.67         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.0016      |
# | loss_ent        | 0.67994785   |
# | loss_kl         | 0.013158011  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.030138802 |
# | loss_vf_loss    | 11.333215    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.01010 |       0.00000 |      53.07510 |       0.00297 |       0.66721
#      -0.01551 |       0.00000 |      39.84819 |       0.00306 |       0.66553
#      -0.01706 |       0.00000 |      36.76955 |       0.00352 |       0.66415
#      -0.01800 |       0.00000 |      34.93572 |       0.00386 |       0.66331
#      -0.01846 |       0.00000 |      33.53212 |       0.00408 |       0.66276
#      -0.01891 |       0.00000 |      32.42079 |       0.00441 |       0.66202
#      -0.01911 |       0.00000 |      31.47746 |       0.00444 |       0.66214
#      -0.01964 |       0.00000 |      30.67013 |       0.00467 |       0.66158
#      -0.01967 |       0.00000 |      29.92953 |       0.00480 |       0.66131
#      -0.02011 |       0.00000 |      29.23583 |       0.00486 |       0.66132
# Evaluating losses...
#      -0.02025 |       0.00000 |      28.87161 |       0.00529 |       0.66027
# ----------------------------------
# | EpLenMean       | 31.4         |
# | EpRewMean       | 31.4         |
# | EpThisIter      | 127          |
# | EpisodesSoFar   | 302          |
# | TimeElapsed     | 5.05         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.211        |
# | loss_ent        | 0.66027296   |
# | loss_kl         | 0.0052854656 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.020252615 |
# | loss_vf_loss    | 28.871607    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00390 |       0.00000 |      72.73448 |       0.00028 |       0.65733
#      -0.00523 |       0.00000 |      64.83298 |       0.00029 |       0.65692
#      -0.00561 |       0.00000 |      61.09344 |       0.00027 |       0.65704
#      -0.00583 |       0.00000 |      58.91003 |       0.00030 |       0.65679
#      -0.00593 |       0.00000 |      57.41243 |       0.00034 |       0.65642
#      -0.00603 |       0.00000 |      56.25224 |       0.00035 |       0.65622
#      -0.00607 |       0.00000 |      55.26334 |       0.00037 |       0.65609
#      -0.00612 |       0.00000 |      54.38956 |       0.00038 |       0.65605
#      -0.00614 |       0.00000 |      53.60268 |       0.00041 |       0.65573
#      -0.00621 |       0.00000 |      52.87800 |       0.00039 |       0.65601
# Evaluating losses...
#      -0.00621 |       0.00000 |      52.50408 |       0.00048 |       0.65505
# -----------------------------------
# | EpLenMean       | 42.5          |
# | EpRewMean       | 42.5          |
# | EpThisIter      | 93            |
# | EpisodesSoFar   | 395           |
# | TimeElapsed     | 7.35          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | 0.295         |
# | loss_ent        | 0.6550512     |
# | loss_kl         | 0.00048406693 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0062067416 |
# | loss_vf_loss    | 52.504078     |
# -----------------------------------
# Logging to bnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdff2995d90>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00187 |       0.00000 |      78.97748 |       0.00016 |       0.69300
#      -0.00719 |       0.00000 |      76.34558 |       0.00168 |       0.69152
#      -0.01200 |       0.00000 |      73.13460 |       0.00499 |       0.68827
#      -0.01538 |       0.00000 |      69.28011 |       0.00683 |       0.68646
#      -0.01724 |       0.00000 |      64.83208 |       0.00834 |       0.68497
#      -0.01816 |       0.00000 |      60.01022 |       0.00901 |       0.68431
#      -0.01982 |       0.00000 |      54.93562 |       0.00914 |       0.68418
#      -0.02103 |       0.00000 |      49.77633 |       0.00935 |       0.68397
#      -0.02244 |       0.00000 |      44.69564 |       0.01034 |       0.68300
#      -0.02365 |       0.00000 |      39.85924 |       0.01059 |       0.68275
# Evaluating losses...
#      -0.02441 |       0.00000 |      37.56202 |       0.00991 |       0.68341
# ----------------------------------
# | EpLenMean       | 20.6         |
# | EpRewMean       | 20.6         |
# | EpThisIter      | 203          |
# | EpisodesSoFar   | 203          |
# | TimeElapsed     | 2.97         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.00964     |
# | loss_ent        | 0.68341285   |
# | loss_kl         | 0.009908844  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.024412025 |
# | loss_vf_loss    | 37.56202     |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00312 |       0.00000 |      81.58801 |       0.00050 |       0.68161
#      -0.00761 |       0.00000 |      75.14011 |       0.00189 |       0.67561
#      -0.00843 |       0.00000 |      69.38009 |       0.00225 |       0.67461
#      -0.00858 |       0.00000 |      64.15652 |       0.00223 |       0.67466
#      -0.00906 |       0.00000 |      59.41584 |       0.00227 |       0.67438
#      -0.00948 |       0.00000 |      55.10831 |       0.00264 |       0.67344
#      -0.00991 |       0.00000 |      51.13687 |       0.00249 |       0.67394
#      -0.01034 |       0.00000 |      47.56942 |       0.00271 |       0.67330
#      -0.01090 |       0.00000 |      44.32574 |       0.00263 |       0.67359
#      -0.01057 |       0.00000 |      41.39948 |       0.00268 |       0.67348
# Evaluating losses...
#      -0.01149 |       0.00000 |      40.05338 |       0.00279 |       0.67322
# ----------------------------------
# | EpLenMean       | 26.6         |
# | EpRewMean       | 26.6         |
# | EpThisIter      | 151          |
# | EpisodesSoFar   | 354          |
# | TimeElapsed     | 5.58         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | -0.0807      |
# | loss_ent        | 0.6732186    |
# | loss_kl         | 0.0027850827 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.01148545  |
# | loss_vf_loss    | 40.05338     |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00040 |       0.00000 |      93.12676 |       0.00019 |       0.67469
#      -0.00067 |       0.00000 |      90.40737 |       0.00025 |       0.67308
#      -0.00067 |       0.00000 |      87.90630 |       0.00031 |       0.67236
#      -0.00045 |       0.00000 |      85.63100 |       0.00032 |       0.67225
#      -0.00165 |       0.00000 |      83.44984 |       0.00032 |       0.67227
#      -0.00104 |       0.00000 |      81.44515 |       0.00032 |       0.67231
#      -0.00136 |       0.00000 |      79.49247 |       0.00031 |       0.67240
#      -0.00132 |       0.00000 |      77.64252 |       0.00034 |       0.67221
#      -0.00123 |       0.00000 |      75.94445 |       0.00037 |       0.67208
#      -0.00155 |       0.00000 |      74.28225 |       0.00034 |       0.67219
# Evaluating losses...
#      -0.00125 |       0.00000 |      73.41949 |       0.00035 |       0.67222
# -----------------------------------
# | EpLenMean       | 36.9          |
# | EpRewMean       | 36.9          |
# | EpThisIter      | 112           |
# | EpisodesSoFar   | 466           |
# | TimeElapsed     | 8.09          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | -0.00642      |
# | loss_ent        | 0.67222154    |
# | loss_kl         | 0.00034536893 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0012515018 |
# | loss_vf_loss    | 73.41949      |
# -----------------------------------
# DNN - Mean reward: 183.545, Std reward: 26.02229765028446
# BNN - Mean reward: 173.205, Std reward: 37.42732925283342
# Logging to dnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdff4c11c10>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00836 |       0.00000 |      82.48325 |       0.00325 |       0.68983
#      -0.01741 |       0.00000 |      69.66510 |       0.00836 |       0.68468
#      -0.01912 |       0.00000 |      44.09813 |       0.00838 |       0.68467
#      -0.02180 |       0.00000 |      22.33900 |       0.00954 |       0.68351
#      -0.02466 |       0.00000 |      15.73257 |       0.01038 |       0.68267
#      -0.02665 |       0.00000 |      14.31156 |       0.01175 |       0.68132
#      -0.02806 |       0.00000 |      13.07666 |       0.01257 |       0.68051
#      -0.02916 |       0.00000 |      11.81603 |       0.01315 |       0.67993
#      -0.02978 |       0.00000 |      10.80821 |       0.01342 |       0.67967
#      -0.03067 |       0.00000 |      10.15432 |       0.01374 |       0.67935
# Evaluating losses...
#      -0.03100 |       0.00000 |       9.89902 |       0.01457 |       0.67854
# ----------------------------------
# | EpLenMean       | 20.9         |
# | EpRewMean       | 20.9         |
# | EpThisIter      | 193          |
# | EpisodesSoFar   | 193          |
# | TimeElapsed     | 2.45         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.000552     |
# | loss_ent        | 0.6785376    |
# | loss_kl         | 0.014565594  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.031002698 |
# | loss_vf_loss    | 9.899017     |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.01075 |       0.00000 |      60.19387 |       0.00247 |       0.66785
#      -0.01533 |       0.00000 |      42.37664 |       0.00293 |       0.66533
#      -0.01646 |       0.00000 |      38.85964 |       0.00337 |       0.66400
#      -0.01713 |       0.00000 |      37.03592 |       0.00370 |       0.66316
#      -0.01747 |       0.00000 |      35.72585 |       0.00381 |       0.66285
#      -0.01779 |       0.00000 |      34.66032 |       0.00414 |       0.66225
#      -0.01799 |       0.00000 |      33.78461 |       0.00423 |       0.66187
#      -0.01828 |       0.00000 |      33.00191 |       0.00449 |       0.66130
#      -0.01856 |       0.00000 |      32.23846 |       0.00454 |       0.66133
#      -0.01868 |       0.00000 |      31.50277 |       0.00469 |       0.66094
# Evaluating losses...
#      -0.01879 |       0.00000 |      31.10637 |       0.00436 |       0.66184
# ----------------------------------
# | EpLenMean       | 35.8         |
# | EpRewMean       | 35.8         |
# | EpThisIter      | 116          |
# | EpisodesSoFar   | 309          |
# | TimeElapsed     | 4.74         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.2          |
# | loss_ent        | 0.66183954   |
# | loss_kl         | 0.0043649776 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.018786578 |
# | loss_vf_loss    | 31.106365    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00300 |       0.00000 |      78.72112 |       0.00027 |       0.65792
#      -0.00427 |       0.00000 |      70.92458 |       0.00024 |       0.65784
#      -0.00460 |       0.00000 |      67.12025 |       0.00025 |       0.65770
#      -0.00478 |       0.00000 |      64.78088 |       0.00026 |       0.65755
#      -0.00487 |       0.00000 |      63.12045 |       0.00028 |       0.65726
#      -0.00494 |       0.00000 |      61.79646 |       0.00030 |       0.65720
#      -0.00493 |       0.00000 |      60.65990 |       0.00031 |       0.65712
#      -0.00501 |       0.00000 |      59.64077 |       0.00032 |       0.65708
#      -0.00503 |       0.00000 |      58.70638 |       0.00033 |       0.65702
#      -0.00503 |       0.00000 |      57.83435 |       0.00033 |       0.65698
# Evaluating losses...
#      -0.00513 |       0.00000 |      57.39333 |       0.00035 |       0.65685
# ----------------------------------
# | EpLenMean       | 45.3         |
# | EpRewMean       | 45.3         |
# | EpThisIter      | 90           |
# | EpisodesSoFar   | 399          |
# | TimeElapsed     | 7.01         |
# | TimestepsSoFar  | 12288        |
# | ev_tdlam_before | 0.261        |
# | loss_ent        | 0.656846     |
# | loss_kl         | 0.0003456744 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.005129088 |
# | loss_vf_loss    | 57.39333     |
# ----------------------------------
# Logging to bnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdff4e27b10>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00109 |       0.00000 |      93.84705 |      5.48e-05 |       0.69309
#      -0.00466 |       0.00000 |      91.07639 |       0.00067 |       0.69247
#      -0.01052 |       0.00000 |      87.49888 |       0.00304 |       0.69012
#      -0.01484 |       0.00000 |      83.00015 |       0.00710 |       0.68612
#      -0.01624 |       0.00000 |      77.72357 |       0.00820 |       0.68505
#      -0.01691 |       0.00000 |      71.82268 |       0.00916 |       0.68411
#      -0.01785 |       0.00000 |      65.54908 |       0.00928 |       0.68399
#      -0.01912 |       0.00000 |      59.17629 |       0.00895 |       0.68430
#      -0.02073 |       0.00000 |      52.93835 |       0.00953 |       0.68373
#      -0.02251 |       0.00000 |      47.01973 |       0.01025 |       0.68301
# Evaluating losses...
#      -0.02325 |       0.00000 |      44.14791 |       0.01060 |       0.68267
# ----------------------------------
# | EpLenMean       | 22.9         |
# | EpRewMean       | 22.9         |
# | EpThisIter      | 178          |
# | EpisodesSoFar   | 178          |
# | TimeElapsed     | 2.95         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.0078      |
# | loss_ent        | 0.6826691    |
# | loss_kl         | 0.010600854  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.023249535 |
# | loss_vf_loss    | 44.147907    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00206 |       0.00000 |      86.70506 |       0.00039 |       0.68114
#      -0.00547 |       0.00000 |      79.59082 |       0.00161 |       0.67570
#      -0.00700 |       0.00000 |      73.15837 |       0.00201 |       0.67431
#      -0.00751 |       0.00000 |      67.43414 |       0.00223 |       0.67363
#      -0.00857 |       0.00000 |      62.22472 |       0.00213 |       0.67404
#      -0.00921 |       0.00000 |      57.50351 |       0.00228 |       0.67365
#      -0.00959 |       0.00000 |      53.18463 |       0.00245 |       0.67322
#      -0.00982 |       0.00000 |      49.38666 |       0.00255 |       0.67306
#      -0.00996 |       0.00000 |      45.88554 |       0.00270 |       0.67266
#      -0.01073 |       0.00000 |      42.74955 |       0.00262 |       0.67298
# Evaluating losses...
#      -0.01075 |       0.00000 |      41.30745 |       0.00268 |       0.67276
# ----------------------------------
# | EpLenMean       | 29.3         |
# | EpRewMean       | 29.3         |
# | EpThisIter      | 142          |
# | EpisodesSoFar   | 320          |
# | TimeElapsed     | 5.6          |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | -0.0889      |
# | loss_ent        | 0.6727569    |
# | loss_kl         | 0.0026834847 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.010750604 |
# | loss_vf_loss    | 41.307453    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00016 |       0.00000 |      96.89734 |       0.00018 |       0.67410
#      -0.00120 |       0.00000 |      93.85361 |       0.00024 |       0.67259
#      -0.00136 |       0.00000 |      91.11202 |       0.00030 |       0.67193
#      -0.00146 |       0.00000 |      88.55539 |       0.00030 |       0.67183
#      -0.00148 |       0.00000 |      86.15934 |       0.00031 |       0.67180
#      -0.00141 |       0.00000 |      84.01334 |       0.00035 |       0.67138
#      -0.00213 |       0.00000 |      81.89555 |       0.00031 |       0.67182
#      -0.00190 |       0.00000 |      79.89726 |       0.00036 |       0.67132
#      -0.00196 |       0.00000 |      77.90450 |       0.00036 |       0.67126
#      -0.00147 |       0.00000 |      76.16307 |       0.00037 |       0.67128
# Evaluating losses...
#      -0.00148 |       0.00000 |      75.27636 |       0.00037 |       0.67126
# -----------------------------------
# | EpLenMean       | 37.8          |
# | EpRewMean       | 37.8          |
# | EpThisIter      | 109           |
# | EpisodesSoFar   | 429           |
# | TimeElapsed     | 8.34          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | -0.0225       |
# | loss_ent        | 0.67126065    |
# | loss_kl         | 0.00037024068 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0014780855 |
# | loss_vf_loss    | 75.27636      |
# -----------------------------------
# DNN - Mean reward: 167.562, Std reward: 44.85300609769651
# BNN - Mean reward: 178.991, Std reward: 33.86040340870144
# Logging to dnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdff4bad9d0>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00830 |       0.00000 |      89.89194 |       0.00344 |       0.68954
#      -0.01444 |       0.00000 |      76.85749 |       0.00797 |       0.68491
#      -0.01585 |       0.00000 |      49.78482 |       0.00822 |       0.68466
#      -0.01832 |       0.00000 |      25.55328 |       0.00842 |       0.68445
#      -0.02140 |       0.00000 |      17.54012 |       0.00982 |       0.68306
#      -0.02394 |       0.00000 |      15.83537 |       0.01154 |       0.68134
#      -0.02544 |       0.00000 |      14.60463 |       0.01247 |       0.68042
#      -0.02647 |       0.00000 |      13.25350 |       0.01312 |       0.67978
#      -0.02721 |       0.00000 |      12.05355 |       0.01314 |       0.67977
#      -0.02758 |       0.00000 |      11.20622 |       0.01381 |       0.67911
# Evaluating losses...
#      -0.02831 |       0.00000 |      10.84922 |       0.01375 |       0.67916
# ----------------------------------
# | EpLenMean       | 23.2         |
# | EpRewMean       | 23.2         |
# | EpThisIter      | 181          |
# | EpisodesSoFar   | 181          |
# | TimeElapsed     | 2.48         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.00129     |
# | loss_ent        | 0.6791626    |
# | loss_kl         | 0.01375101   |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.028306177 |
# | loss_vf_loss    | 10.849217    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.01141 |       0.00000 |      56.78954 |       0.00302 |       0.66660
#      -0.01697 |       0.00000 |      40.47706 |       0.00292 |       0.66530
#      -0.01837 |       0.00000 |      36.55261 |       0.00346 |       0.66366
#      -0.01900 |       0.00000 |      34.33754 |       0.00374 |       0.66296
#      -0.01930 |       0.00000 |      32.75965 |       0.00403 |       0.66225
#      -0.01990 |       0.00000 |      31.58368 |       0.00434 |       0.66149
#      -0.02015 |       0.00000 |      30.66763 |       0.00448 |       0.66119
#      -0.02040 |       0.00000 |      29.93489 |       0.00472 |       0.66062
#      -0.02063 |       0.00000 |      29.31934 |       0.00473 |       0.66066
#      -0.02090 |       0.00000 |      28.79285 |       0.00499 |       0.66010
# Evaluating losses...
#      -0.02096 |       0.00000 |      28.51165 |       0.00448 |       0.66145
# ----------------------------------
# | EpLenMean       | 33           |
# | EpRewMean       | 33           |
# | EpThisIter      | 121          |
# | EpisodesSoFar   | 302          |
# | TimeElapsed     | 4.62         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.225        |
# | loss_ent        | 0.66145283   |
# | loss_kl         | 0.004478732  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.020956453 |
# | loss_vf_loss    | 28.511648    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00328 |       0.00000 |      81.41457 |       0.00028 |       0.65762
#      -0.00460 |       0.00000 |      70.58614 |       0.00029 |       0.65696
#      -0.00492 |       0.00000 |      65.74026 |       0.00028 |       0.65716
#      -0.00507 |       0.00000 |      62.98040 |       0.00030 |       0.65684
#      -0.00514 |       0.00000 |      61.12583 |       0.00030 |       0.65691
#      -0.00519 |       0.00000 |      59.73890 |       0.00032 |       0.65670
#      -0.00528 |       0.00000 |      58.62314 |       0.00034 |       0.65646
#      -0.00527 |       0.00000 |      57.64365 |       0.00034 |       0.65654
#      -0.00532 |       0.00000 |      56.78451 |       0.00036 |       0.65632
#      -0.00536 |       0.00000 |      56.01281 |       0.00035 |       0.65649
# Evaluating losses...
#      -0.00542 |       0.00000 |      55.63237 |       0.00034 |       0.65662
# -----------------------------------
# | EpLenMean       | 47.6          |
# | EpRewMean       | 47.6          |
# | EpThisIter      | 80            |
# | EpisodesSoFar   | 382           |
# | TimeElapsed     | 6.79          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | 0.282         |
# | loss_ent        | 0.6566248     |
# | loss_kl         | 0.00033614194 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0054162554 |
# | loss_vf_loss    | 55.632374     |
# -----------------------------------
# Logging to bnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdff6d30e90>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00181 |       0.00000 |      83.62863 |      9.11e-05 |       0.69306
#      -0.00788 |       0.00000 |      80.76478 |       0.00118 |       0.69198
#      -0.01574 |       0.00000 |      77.57241 |       0.00505 |       0.68817
#      -0.01905 |       0.00000 |      73.67188 |       0.00844 |       0.68485
#      -0.01968 |       0.00000 |      69.07552 |       0.00966 |       0.68366
#      -0.02038 |       0.00000 |      63.94521 |       0.00951 |       0.68380
#      -0.02177 |       0.00000 |      58.56540 |       0.00934 |       0.68396
#      -0.02322 |       0.00000 |      53.11386 |       0.00960 |       0.68369
#      -0.02469 |       0.00000 |      47.79222 |       0.01014 |       0.68317
#      -0.02634 |       0.00000 |      42.68106 |       0.01060 |       0.68270
# Evaluating losses...
#      -0.02664 |       0.00000 |      40.23510 |       0.01201 |       0.68133
# ----------------------------------
# | EpLenMean       | 20.5         |
# | EpRewMean       | 20.5         |
# | EpThisIter      | 190          |
# | EpisodesSoFar   | 190          |
# | TimeElapsed     | 2.86         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.00589      |
# | loss_ent        | 0.68133444   |
# | loss_kl         | 0.012009255  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.026644062 |
# | loss_vf_loss    | 40.2351      |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00384 |       0.00000 |     102.17238 |       0.00062 |       0.67951
#      -0.00827 |       0.00000 |      94.15210 |       0.00185 |       0.67363
#      -0.00932 |       0.00000 |      87.01828 |       0.00237 |       0.67200
#      -0.01012 |       0.00000 |      80.56662 |       0.00232 |       0.67238
#      -0.01047 |       0.00000 |      74.69437 |       0.00239 |       0.67223
#      -0.01105 |       0.00000 |      69.29961 |       0.00267 |       0.67139
#      -0.01178 |       0.00000 |      64.34313 |       0.00252 |       0.67205
#      -0.01239 |       0.00000 |      59.75700 |       0.00276 |       0.67153
#      -0.01208 |       0.00000 |      55.55917 |       0.00274 |       0.67161
#      -0.01283 |       0.00000 |      51.76817 |       0.00291 |       0.67118
# Evaluating losses...
#      -0.01283 |       0.00000 |      49.98854 |       0.00283 |       0.67123
# ----------------------------------
# | EpLenMean       | 34.8         |
# | EpRewMean       | 34.8         |
# | EpThisIter      | 123          |
# | EpisodesSoFar   | 313          |
# | TimeElapsed     | 5.34         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | -0.0478      |
# | loss_ent        | 0.6712299    |
# | loss_kl         | 0.002832363  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.012833685 |
# | loss_vf_loss    | 49.988537    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00035 |       0.00000 |      97.48850 |       0.00012 |       0.67266
#      -0.00043 |       0.00000 |      94.99166 |       0.00019 |       0.67109
# ...
#      -0.00448 |       0.00000 |      61.15100 |       0.00025 |       0.65453
#      -0.00453 |       0.00000 |      59.47931 |       0.00027 |       0.65415
#      -0.00460 |       0.00000 |      58.17686 |       0.00029 |       0.65402
#      -0.00462 |       0.00000 |      57.12856 |       0.00030 |       0.65390
#      -0.00467 |       0.00000 |      56.20119 |       0.00030 |       0.65392
#      -0.00467 |       0.00000 |      55.36085 |       0.00032 |       0.65373
#      -0.00470 |       0.00000 |      54.59363 |       0.00031 |       0.65391
# Evaluating losses...
#      -0.00477 |       0.00000 |      54.20808 |       0.00031 |       0.65388
# -----------------------------------
# | EpLenMean       | 43            |
# | EpRewMean       | 43            |
# | EpThisIter      | 91            |
# | EpisodesSoFar   | 407           |
# | TimeElapsed     | 6.81          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | 0.258         |
# | loss_ent        | 0.6538765     |
# | loss_kl         | 0.00030769422 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0047738575 |
# | loss_vf_loss    | 54.208076     |
# -----------------------------------
# Logging to bnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdfc408fc10>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00140 |       0.00000 |      84.32919 |       0.00013 |       0.69302
#      -0.00544 |       0.00000 |      81.70689 |       0.00102 |       0.69215
#      -0.01130 |       0.00000 |      78.45866 |       0.00439 |       0.68882
#      -0.01491 |       0.00000 |      74.36389 |       0.00728 |       0.68598
#      -0.01554 |       0.00000 |      69.48770 |       0.00824 |       0.68505
#      -0.01663 |       0.00000 |      64.10631 |       0.00903 |       0.68427
#      -0.01798 |       0.00000 |      58.49514 |       0.00837 |       0.68491
#      -0.01968 |       0.00000 |      52.89897 |       0.00941 |       0.68388
#      -0.02129 |       0.00000 |      47.38292 |       0.01024 |       0.68307
#      -0.02266 |       0.00000 |      42.10096 |       0.01078 |       0.68254
# Evaluating losses...
#      -0.02289 |       0.00000 |      39.55902 |       0.01239 |       0.68097
# ----------------------------------
# | EpLenMean       | 20.9         |
# | EpRewMean       | 20.9         |
# | EpThisIter      | 193          |
# | EpisodesSoFar   | 193          |
# | TimeElapsed     | 2.96         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.00518     |
# | loss_ent        | 0.6809677    |
# | loss_kl         | 0.012389522  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.022893399 |
# | loss_vf_loss    | 39.559025    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00307 |       0.00000 |      90.68271 |       0.00040 |       0.68042
#      -0.00764 |       0.00000 |      82.90108 |       0.00165 |       0.67455
#      -0.00876 |       0.00000 |      76.05819 |       0.00201 |       0.67325
#      -0.00894 |       0.00000 |      69.98748 |       0.00227 |       0.67248
#      -0.00921 |       0.00000 |      64.47925 |       0.00239 |       0.67211
#      -0.00966 |       0.00000 |      59.51676 |       0.00230 |       0.67237
#      -0.00996 |       0.00000 |      55.07996 |       0.00246 |       0.67193
#      -0.01048 |       0.00000 |      51.01852 |       0.00268 |       0.67133
#      -0.01041 |       0.00000 |      47.39187 |       0.00272 |       0.67118
#      -0.01065 |       0.00000 |      44.14685 |       0.00300 |       0.67047
# Evaluating losses...
#      -0.01102 |       0.00000 |      42.65602 |       0.00260 |       0.67166
# ----------------------------------
# | EpLenMean       | 31.2         |
# | EpRewMean       | 31.2         |
# | EpThisIter      | 134          |
# | EpisodesSoFar   | 327          |
# | TimeElapsed     | 5.44         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | -0.0825      |
# | loss_ent        | 0.6716564    |
# | loss_kl         | 0.0026020957 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.01101614  |
# | loss_vf_loss    | 42.65602     |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00047 |       0.00000 |      78.51949 |       0.00016 |       0.67117
#      -0.00069 |       0.00000 |      76.36925 |       0.00025 |       0.66930
#      -0.00086 |       0.00000 |      74.40067 |       0.00028 |       0.66876
#      -0.00130 |       0.00000 |      72.58837 |       0.00031 |       0.66837
#      -0.00148 |       0.00000 |      70.80418 |       0.00030 |       0.66836
#      -0.00179 |       0.00000 |      69.16765 |       0.00028 |       0.66860
#      -0.00196 |       0.00000 |      67.60917 |       0.00033 |       0.66826
#      -0.00185 |       0.00000 |      66.04960 |       0.00034 |       0.66814
#      -0.00157 |       0.00000 |      64.66008 |       0.00034 |       0.66813
#      -0.00211 |       0.00000 |      63.27459 |       0.00033 |       0.66835
# Evaluating losses...
#      -0.00199 |       0.00000 |      62.56960 |       0.00035 |       0.66819
# -----------------------------------
# | EpLenMean       | 34.5          |
# | EpRewMean       | 34.5          |
# | EpThisIter      | 124           |
# | EpisodesSoFar   | 451           |
# | TimeElapsed     | 7.93          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | -0.0124       |
# | loss_ent        | 0.6681947     |
# | loss_kl         | 0.00035308435 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0019911614 |
# | loss_vf_loss    | 62.569603     |
# -----------------------------------
# DNN - Mean reward: 162.273, Std reward: 51.401755524495464
# BNN - Mean reward: 171.179, Std reward: 41.93505644445945
# Logging to dnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdfc6794e10>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00848 |       0.00000 |      87.37868 |       0.00387 |       0.68933
#      -0.01457 |       0.00000 |      74.53916 |       0.00814 |       0.68512
#      -0.01634 |       0.00000 |      48.03864 |       0.00808 |       0.68517
#      -0.01837 |       0.00000 |      24.44617 |       0.00906 |       0.68420
#      -0.02044 |       0.00000 |      17.04923 |       0.00975 |       0.68352
#      -0.02234 |       0.00000 |      15.63136 |       0.01061 |       0.68266
#      -0.02362 |       0.00000 |      14.57283 |       0.01203 |       0.68127
#      -0.02515 |       0.00000 |      13.40151 |       0.01266 |       0.68066
#      -0.02545 |       0.00000 |      12.35264 |       0.01277 |       0.68054
#      -0.02607 |       0.00000 |      11.55378 |       0.01326 |       0.68007
# Evaluating losses...
#      -0.02681 |       0.00000 |      11.21743 |       0.01447 |       0.67888
# ----------------------------------
# | EpLenMean       | 21.6         |
# | EpRewMean       | 21.6         |
# | EpThisIter      | 186          |
# | EpisodesSoFar   | 186          |
# | TimeElapsed     | 2.43         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.00311     |
# | loss_ent        | 0.67888075   |
# | loss_kl         | 0.014471149  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.026810039 |
# | loss_vf_loss    | 11.217433    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.01034 |       0.00000 |      53.99674 |       0.00254 |       0.66807
#      -0.01607 |       0.00000 |      39.54164 |       0.00309 |       0.66471
#      -0.01735 |       0.00000 |      36.61497 |       0.00337 |       0.66384
#      -0.01778 |       0.00000 |      34.93766 |       0.00369 |       0.66298
#      -0.01810 |       0.00000 |      33.64233 |       0.00387 |       0.66251
#      -0.01857 |       0.00000 |      32.62545 |       0.00398 |       0.66227
#      -0.01882 |       0.00000 |      31.76354 |       0.00416 |       0.66182
#      -0.01901 |       0.00000 |      30.99910 |       0.00428 |       0.66157
#      -0.01927 |       0.00000 |      30.31049 |       0.00439 |       0.66133
#      -0.01946 |       0.00000 |      29.68988 |       0.00442 |       0.66131
# Evaluating losses...
#      -0.01967 |       0.00000 |      29.34190 |       0.00448 |       0.66120
# ----------------------------------
# | EpLenMean       | 33.5         |
# | EpRewMean       | 33.5         |
# | EpThisIter      | 128          |
# | EpisodesSoFar   | 314          |
# | TimeElapsed     | 4.56         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.213        |
# | loss_ent        | 0.66119564   |
# | loss_kl         | 0.004476316  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.019674027 |
# | loss_vf_loss    | 29.341896    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00301 |       0.00000 |      74.91171 |       0.00025 |       0.65889
#      -0.00462 |       0.00000 |      66.74972 |       0.00026 |       0.65829
#      -0.00494 |       0.00000 |      62.82246 |       0.00027 |       0.65830
#      -0.00514 |       0.00000 |      60.50002 |       0.00028 |       0.65815
#      -0.00531 |       0.00000 |      58.87165 |       0.00029 |       0.65794
#      -0.00540 |       0.00000 |      57.60412 |       0.00031 |       0.65775
#      -0.00547 |       0.00000 |      56.55768 |       0.00032 |       0.65775
#      -0.00554 |       0.00000 |      55.61996 |       0.00033 |       0.65763
#      -0.00558 |       0.00000 |      54.76657 |       0.00036 |       0.65737
#      -0.00564 |       0.00000 |      53.98766 |       0.00035 |       0.65741
# Evaluating losses...
#      -0.00568 |       0.00000 |      53.60485 |       0.00033 |       0.65762
# -----------------------------------
# | EpLenMean       | 44            |
# | EpRewMean       | 44            |
# | EpThisIter      | 91            |
# | EpisodesSoFar   | 405           |
# | TimeElapsed     | 6.69          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | 0.278         |
# | loss_ent        | 0.65762395    |
# | loss_kl         | 0.00033273027 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.005679572  |
# | loss_vf_loss    | 53.60485      |
# -----------------------------------
# Logging to bnn_cartpole
# ********** Iteration 0 ************
# /usr/local/anaconda3/envs/slime-rl/lib/python3.7/site-packages/stable_baselines/common/callbacks.py:287: UserWarning: Training and eval env are not of the same type<TimeLimit<CartPoleEnv<CartPole-v0>>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fdfc6bade90>
#   "{} != {}".format(self.training_env, self.eval_env))
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00191 |       0.00000 |      85.57808 |       0.00012 |       0.69302
#      -0.00779 |       0.00000 |      82.83141 |       0.00130 |       0.69183
#      -0.01424 |       0.00000 |      79.84222 |       0.00492 |       0.68823
#      -0.01779 |       0.00000 |      76.42071 |       0.00784 |       0.68534
#      -0.01901 |       0.00000 |      72.52492 |       0.00870 |       0.68450
#      -0.01982 |       0.00000 |      68.14018 |       0.00907 |       0.68412
#      -0.02117 |       0.00000 |      63.38713 |       0.00913 |       0.68405
#      -0.02237 |       0.00000 |      58.46276 |       0.00962 |       0.68357
#      -0.02379 |       0.00000 |      53.48033 |       0.01000 |       0.68320
#      -0.02514 |       0.00000 |      48.47550 |       0.01054 |       0.68266
# Evaluating losses...
#      -0.02595 |       0.00000 |      45.98987 |       0.01097 |       0.68223
# ----------------------------------
# | EpLenMean       | 21.6         |
# | EpRewMean       | 21.6         |
# | EpThisIter      | 185          |
# | EpisodesSoFar   | 185          |
# | TimeElapsed     | 2.88         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.014        |
# | loss_ent        | 0.682234     |
# | loss_kl         | 0.010972053  |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.025946205 |
# | loss_vf_loss    | 45.989872    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00218 |       0.00000 |      95.95699 |       0.00034 |       0.68151
#      -0.00598 |       0.00000 |      89.67906 |       0.00147 |       0.67588
#      -0.00689 |       0.00000 |      83.92349 |       0.00208 |       0.67378
#      -0.00776 |       0.00000 |      78.64329 |       0.00221 |       0.67342
#      -0.00879 |       0.00000 |      73.74648 |       0.00234 |       0.67306
#      -0.00884 |       0.00000 |      69.14793 |       0.00225 |       0.67334
#      -0.01002 |       0.00000 |      64.85023 |       0.00242 |       0.67291
#      -0.01032 |       0.00000 |      60.85659 |       0.00250 |       0.67266
#      -0.01039 |       0.00000 |      57.11918 |       0.00272 |       0.67215
#      -0.01091 |       0.00000 |      53.67296 |       0.00256 |       0.67263
# Evaluating losses...
#      -0.01076 |       0.00000 |      52.00222 |       0.00276 |       0.67213
# ----------------------------------
# | EpLenMean       | 31.2         |
# | EpRewMean       | 31.2         |
# | EpThisIter      | 139          |
# | EpisodesSoFar   | 324          |
# | TimeElapsed     | 5.34         |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | -0.0633      |
# | loss_ent        | 0.67212903   |
# | loss_kl         | 0.0027579453 |
# | loss_pol_entpen | 0.0          |
# | loss_pol_surr   | -0.010763181 |
# | loss_vf_loss    | 52.002216    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00022 |       0.00000 |     107.65441 |       0.00016 |       0.67402
#      -0.00093 |       0.00000 |     105.09029 |       0.00025 |       0.67231
#      -0.00132 |       0.00000 |     102.75381 |       0.00033 |       0.67147
#      -0.00161 |       0.00000 |     100.53202 |       0.00033 |       0.67156
#      -0.00137 |       0.00000 |      98.41697 |       0.00035 |       0.67135
#      -0.00169 |       0.00000 |      96.38531 |       0.00039 |       0.67101
#      -0.00161 |       0.00000 |      94.46598 |       0.00036 |       0.67133
#      -0.00173 |       0.00000 |      92.57793 |       0.00035 |       0.67141
#      -0.00211 |       0.00000 |      90.75500 |       0.00035 |       0.67125
#      -0.00194 |       0.00000 |      89.00827 |       0.00038 |       0.67114
# Evaluating losses...
#      -0.00205 |       0.00000 |      88.10396 |       0.00034 |       0.67127
# -----------------------------------
# | EpLenMean       | 39.5          |
# | EpRewMean       | 39.5          |
# | EpThisIter      | 104           |
# | EpisodesSoFar   | 428           |
# | TimeElapsed     | 7.79          |
# | TimestepsSoFar  | 12288         |
# | ev_tdlam_before | -0.0212       |
# | loss_ent        | 0.6712705     |
# | loss_kl         | 0.00034287063 |
# | loss_pol_entpen | 0.0           |
# | loss_pol_surr   | -0.0020487579 |
# | loss_vf_loss    | 88.10396      |
# -----------------------------------
# DNN - Mean reward: 180.935, Std reward: 30.207396031435746

# %%
df.head()
# Out:
#     Seed  BNN reward    BNN std  DNN reward    DNN std
# 0  600.0     189.033  19.244737     181.186  30.742241
