# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.1
K_epoch       = 3
T_horizon     = 20

class PPO(nn.Module):
    def __init__(self):
        super(PPO, self).__init__()
        self.data = []
        
        self.fc1   = nn.Linear(4,256)
        self.fc_pi = nn.Linear(256,2)
        self.fc_v  = nn.Linear(256,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self, x, softmax_dim = 0):
        x = F.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim=softmax_dim)
        return prob
    
    def v(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_v(x)
        return v
      
    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, prob_a_lst, done_lst = [], [], [], [], [], []
        for transition in self.data:
            s, a, r, s_prime, prob_a, done = transition
            
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            prob_a_lst.append([prob_a])
            done_mask = 0 if done else 1
            done_lst.append([done_mask])
            
        s,a,r,s_prime,done_mask, prob_a = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
                                          torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
                                          torch.tensor(done_lst, dtype=torch.float), torch.tensor(prob_a_lst)
        self.data = []
        return s, a, r, s_prime, done_mask, prob_a
        
    def train_net(self):
        s, a, r, s_prime, done_mask, prob_a = self.make_batch()

        for i in range(K_epoch):
            td_target = r + gamma * self.v(s_prime) * done_mask
            delta = td_target - self.v(s)
            delta = delta.detach().numpy()

            advantage_lst = []
            advantage = 0.0
            for delta_t in delta[::-1]:
                advantage = gamma * lmbda * advantage + delta_t[0]
                advantage_lst.append([advantage])
            advantage_lst.reverse()
            advantage = torch.tensor(advantage_lst, dtype=torch.float)

            pi = self.pi(s, softmax_dim=1)
            pi_a = pi.gather(1,a)
            ratio = torch.exp(torch.log(pi_a) - torch.log(prob_a))  # a/b == exp(log(a)-log(b))

            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantage
            loss = -torch.min(surr1, surr2) + F.smooth_l1_loss(self.v(s) , td_target.detach())

            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
        
def main():
    env = gym.make('CartPole-v1')
    model = PPO()
    score = 0.0
    print_interval = 20

    for n_epi in range(10000):
        s = env.reset()
        done = False
        while not done:
            for t in range(T_horizon):
                prob = model.pi(torch.from_numpy(s).float())
                m = Categorical(prob)
                a = m.sample().item()
                s_prime, r, done, info = env.step(a)

                model.put_data((s, a, r/100.0, s_prime, prob[a].item(), done))
                s = s_prime

                score += r
                if done:
                    break

            model.train_net()

        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {:.1f}".format(n_epi, score/print_interval))
            score = 0.0

    env.close()

if __name__ == '__main__':
    main()
# Out:
# # of episode :20, avg score : 25.2
# # of episode :40, avg score : 14.1
# # of episode :60, avg score : 23.4
# # of episode :80, avg score : 29.6
# # of episode :100, avg score : 30.2
# # of episode :120, avg score : 45.0
# # of episode :140, avg score : 60.8
# # of episode :160, avg score : 104.9
# # of episode :180, avg score : 169.4
# # of episode :200, avg score : 177.8
# # of episode :220, avg score : 172.0
# # of episode :240, avg score : 300.2
# # of episode :260, avg score : 327.2
# # of episode :280, avg score : 336.3
# # of episode :300, avg score : 305.6
# # of episode :320, avg score : 369.6
# # of episode :340, avg score : 354.6
# # of episode :360, avg score : 456.9
# # of episode :380, avg score : 339.1
# # of episode :400, avg score : 398.5
# # of episode :420, avg score : 456.2
# # of episode :440, avg score : 422.6
# # of episode :460, avg score : 491.8
# # of episode :480, avg score : 403.6
# # of episode :500, avg score : 235.4
# # of episode :520, avg score : 144.2
# # of episode :540, avg score : 152.5
# # of episode :560, avg score : 152.4
# # of episode :580, avg score : 158.5
# # of episode :600, avg score : 157.6
# # of episode :620, avg score : 159.2
# # of episode :640, avg score : 205.0
# # of episode :660, avg score : 294.4
# # of episode :680, avg score : 431.9
# # of episode :700, avg score : 474.4
# # of episode :720, avg score : 375.4
# # of episode :740, avg score : 254.9
# # of episode :760, avg score : 323.4
# # of episode :780, avg score : 469.1
# # of episode :800, avg score : 500.0
# # of episode :820, avg score : 319.0
# # of episode :840, avg score : 355.8
# # of episode :860, avg score : 348.6
# # of episode :880, avg score : 347.9
# # of episode :900, avg score : 370.2
# # of episode :920, avg score : 171.5
# # of episode :940, avg score : 343.4
# # of episode :960, avg score : 343.6
# # of episode :980, avg score : 382.5
# # of episode :1000, avg score : 428.6
# # of episode :1020, avg score : 337.5
# # of episode :1040, avg score : 305.7
# # of episode :1060, avg score : 422.5
# # of episode :1080, avg score : 260.1
# # of episode :1100, avg score : 165.3
# # of episode :1120, avg score : 241.1
# # of episode :1140, avg score : 360.2
# # of episode :1160, avg score : 279.3
# # of episode :1180, avg score : 181.9
# # of episode :1200, avg score : 169.7
# # of episode :1220, avg score : 380.0
# # of episode :1240, avg score : 282.5
# # of episode :1260, avg score : 303.2
# # of episode :1280, avg score : 318.4
# # of episode :1300, avg score : 357.6
# # of episode :1320, avg score : 411.3
# # of episode :1340, avg score : 247.4
# # of episode :1360, avg score : 261.8
# # of episode :1380, avg score : 240.8
# # of episode :1400, avg score : 287.0
# # of episode :1420, avg score : 305.1
# # of episode :1440, avg score : 126.7
# # of episode :1460, avg score : 164.7
# # of episode :1480, avg score : 239.7
# # of episode :1500, avg score : 391.6
# # of episode :1520, avg score : 375.4
# # of episode :1540, avg score : 252.8
# # of episode :1560, avg score : 373.2
# # of episode :1580, avg score : 304.0
# # of episode :1600, avg score : 392.9
# # of episode :1620, avg score : 382.8
# # of episode :1640, avg score : 244.6
# # of episode :1660, avg score : 379.1
# # of episode :1680, avg score : 280.6
# # of episode :1700, avg score : 244.1
# # of episode :1720, avg score : 158.7
# # of episode :1740, avg score : 168.3
# # of episode :1760, avg score : 156.8
# # of episode :1780, avg score : 164.7
# # of episode :1800, avg score : 214.3
# # of episode :1820, avg score : 394.7
# # of episode :1840, avg score : 335.6
# # of episode :1860, avg score : 410.3
# # of episode :1880, avg score : 452.9
# # of episode :1900, avg score : 497.6
# # of episode :1920, avg score : 500.0
# # of episode :1940, avg score : 255.3
# # of episode :1960, avg score : 187.9
# # of episode :1980, avg score : 227.3
# # of episode :2000, avg score : 223.2
# # of episode :2020, avg score : 205.3
# # of episode :2040, avg score : 257.8
# # of episode :2060, avg score : 229.9
# # of episode :2080, avg score : 194.2
# # of episode :2100, avg score : 289.1
# # of episode :2120, avg score : 309.8
# # of episode :2140, avg score : 176.2
# # of episode :2160, avg score : 137.1
# # of episode :2180, avg score : 140.8
# # of episode :2200, avg score : 179.7
# # of episode :2220, avg score : 321.4
# # of episode :2240, avg score : 244.7
# # of episode :2260, avg score : 404.1
# # of episode :2280, avg score : 411.7
# # of episode :2300, avg score : 396.6
# # of episode :2320, avg score : 409.2
# # of episode :2340, avg score : 407.5
# # of episode :2360, avg score : 356.9
# # of episode :2380, avg score : 453.5
# # of episode :2400, avg score : 203.8
# # of episode :2420, avg score : 254.6
# # of episode :2440, avg score : 269.4
# # of episode :2460, avg score : 404.8
# # of episode :2480, avg score : 213.3
# # of episode :2500, avg score : 99.0
# # of episode :2520, avg score : 89.8
# # of episode :2540, avg score : 106.5
# # of episode :2560, avg score : 148.2
# # of episode :2580, avg score : 140.6
# # of episode :2600, avg score : 160.2
# # of episode :2620, avg score : 158.7
# # of episode :2640, avg score : 294.6
# # of episode :2660, avg score : 401.8
# # of episode :2680, avg score : 253.5
# # of episode :2700, avg score : 234.7
# # of episode :2720, avg score : 251.6
# # of episode :2740, avg score : 164.6
# # of episode :2760, avg score : 322.7
# # of episode :2780, avg score : 401.2
# # of episode :2800, avg score : 329.4
# # of episode :2820, avg score : 346.9
# # of episode :2840, avg score : 294.1
# # of episode :2860, avg score : 362.7
# # of episode :2880, avg score : 351.1
# # of episode :2900, avg score : 290.4
# # of episode :2920, avg score : 247.7
# # of episode :2940, avg score : 164.1
# # of episode :2960, avg score : 165.8
# # of episode :2980, avg score : 312.1
# # of episode :3000, avg score : 241.9
# # of episode :3020, avg score : 210.2
# # of episode :3040, avg score : 142.8
# # of episode :3060, avg score : 151.8
# # of episode :3080, avg score : 166.1
# # of episode :3100, avg score : 189.4
# # of episode :3120, avg score : 231.2
# # of episode :3140, avg score : 290.8
# # of episode :3160, avg score : 385.9
# # of episode :3180, avg score : 381.4
# # of episode :3200, avg score : 221.6
# # of episode :3220, avg score : 244.8
# # of episode :3240, avg score : 284.6
# # of episode :3260, avg score : 280.9
# # of episode :3280, avg score : 197.3
# # of episode :3300, avg score : 178.0
# # of episode :3320, avg score : 222.3
# # of episode :3340, avg score : 170.4
# # of episode :3360, avg score : 183.4
# # of episode :3380, avg score : 180.5
# # of episode :3400, avg score : 249.4
# # of episode :3420, avg score : 368.1
# # of episode :3440, avg score : 342.6
# # of episode :3460, avg score : 346.6
# # of episode :3480, avg score : 304.1
# # of episode :3500, avg score : 294.4
# # of episode :3520, avg score : 256.9
# # of episode :3540, avg score : 241.9
# # of episode :3560, avg score : 312.1
# # of episode :3580, avg score : 361.6
# # of episode :3600, avg score : 216.4
# # of episode :3620, avg score : 213.9
# # of episode :3640, avg score : 225.8
# # of episode :3660, avg score : 211.6
# # of episode :3680, avg score : 254.4
# # of episode :3700, avg score : 368.9
# # of episode :3720, avg score : 269.7
# # of episode :3740, avg score : 152.7
# # of episode :3760, avg score : 113.6
# # of episode :3780, avg score : 134.4
# # of episode :3800, avg score : 155.1
# # of episode :3820, avg score : 168.8
# # of episode :3840, avg score : 202.2
# # of episode :3860, avg score : 321.1
# # of episode :3880, avg score : 331.8
# # of episode :3900, avg score : 327.4
# # of episode :3920, avg score : 331.2
# # of episode :3940, avg score : 342.4
# # of episode :3960, avg score : 406.6
# # of episode :3980, avg score : 388.9
# # of episode :4000, avg score : 246.1
# # of episode :4020, avg score : 167.0
# # of episode :4040, avg score : 319.8
# # of episode :4060, avg score : 122.8
# # of episode :4080, avg score : 130.2
# # of episode :4100, avg score : 107.0
# # of episode :4120, avg score : 118.5
# # of episode :4140, avg score : 157.9
# # of episode :4160, avg score : 191.1
# # of episode :4180, avg score : 204.0
# # of episode :4200, avg score : 281.4
# # of episode :4220, avg score : 283.1
# # of episode :4240, avg score : 371.4
# # of episode :4260, avg score : 226.2
# # of episode :4280, avg score : 145.8
# # of episode :4300, avg score : 326.7
# # of episode :4320, avg score : 446.6
# # of episode :4340, avg score : 404.6
# # of episode :4360, avg score : 438.7
# # of episode :4380, avg score : 425.1
# # of episode :4400, avg score : 497.3
# # of episode :4420, avg score : 500.0
# # of episode :4440, avg score : 473.0
# # of episode :4460, avg score : 396.9
# # of episode :4480, avg score : 294.4
# # of episode :4500, avg score : 482.3
# # of episode :4520, avg score : 454.7
# # of episode :4540, avg score : 468.4
# # of episode :4560, avg score : 361.1
# # of episode :4580, avg score : 377.0
# # of episode :4600, avg score : 379.1
# # of episode :4620, avg score : 268.2
